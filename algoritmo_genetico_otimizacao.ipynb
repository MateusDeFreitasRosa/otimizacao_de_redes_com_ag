# %%
## Algoritmo genético para encontrar melhores parametros

# %% [markdown]
# ## Carregamento das bases

# %%
from info_dataset import *
import random
import numpy as np
#from EchoStateNetwork import EchoStateNetwork
from esn import ESN
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from scipy import signal
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
# Desativa a notação científica
np.set_printoptions(suppress=True)

# %% [markdown]
# ## Obter dados

# %%
# Obter dados ATIVOS. Pacientes que tiveram coma e tiveram desfecho de vida.
filesname = get_name_files_from(PATH_DATA['ativos'])
dataset_ativos = get_dataset_from_path_filename(PATH_DATA['ativos'], filesname)
len(dataset_ativos)
# Out:
# 42

# %%
# Obter dados OME. Pacientes que tiveram coma e tiveram desfecho de Morte incefálica.
filesname = get_name_files_from(PATH_DATA['ome'])
dataset_ome = get_dataset_from_path_filename(PATH_DATA['ome'], filesname)
len(dataset_ome)
# Out:
# 15

# %%
## Percentual de desfecho de morte celebral:
round((len(dataset_ome) / (len(dataset_ome) + len(dataset_ativos)))*100, 3)
# Out:
# 26.316

# %%
[fs['fs'][0][0] for fs in dataset_ativos]
# Out:
# [400,
#  400,
#  400,
#  400,
#  400,
#  400,
#  400,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  400,
#  600,
#  600,
#  600,
#  600,
#  200,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200,
#  200]

# %% [markdown]
# ## Padronizar dimensionalidade.

# %% [markdown]
# **Inicialmente padronizar as dimensionalidades para a menor**

# %%
def padroniza_hz(dataset):
    min_hz = min([fs['fs'][0][0] for fs in dataset])
    incremento = 1/min_hz
    
    for enum, data in enumerate(dataset):
        
        
        # Reamostrar para 100 Hz
        resampled_signal_xn = signal.decimate(data['XN'], data['fs'][0][0]//min_hz)
        resampled_signal_time = np.arange(0, data['XN'][0].shape/min_hz, incremento)
        
        dataset[enum]['fs']=min_hz
        dataset[enum]['XN'] = resampled_signal_xn
        dataset[enum]['t'] = resampled_signal_time
    return dataset

# %%
dataset_ome = padroniza_hz(dataset_ome)
[fs['fs'] for fs in dataset_ome]
# Out:
# [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]

# %%
dataset_ativos = padroniza_hz(dataset_ativos)
[fs['fs'] for fs in dataset_ativos]
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100]

# %% [markdown]
# ## Seleciona os dados escolhidos pelo especialista

# %%
def get_signals_for_interval(dataset, label, seconds=2):
    
    dataset_signals = []
    for enum, data in enumerate(dataset):
        print('- Processing data: {}'.format(enum))
        interval_lists = [(interval.min(), interval.max()) for interval in data['epochsTime'][0]]
        hz = data['fs']
        for i_min, i_max in interval_lists:
            print('\t- Process --> imin: {} - imax: {}'.format(i_min, i_max))
            error_adjustment = 1 / hz
            indexes = np.where(((data['t'] >= i_min) & (data['t'] < i_max+error_adjustment) ))[0]
            if len(indexes) > seconds * hz:
                indexes = indexes[:int(seconds * hz)]

            
            print('\t\t- Values: {}'.format(data['XN'][:, indexes].shape))
            dataset_signals.append(data['XN'][:, indexes])
        print('Now dataset is: {}'.format(np.asarray(dataset_signals).shape))
        
    return np.asarray(dataset_signals), [label] * len(dataset_signals)

# %%
## Junta os sinais considerando a quantidade de hz e quantidade de segundos
signals_alive, labels_alive = get_signals_for_interval(dataset_ativos, 0, seconds=1)
signals_alive.shape
# Out:
# - Processing data: 0
# 	- Process --> imin: 20.0 - imax: 22.0
# 		- Values: (20, 100)
# 	- Process --> imin: 22.0 - imax: 24.0
# 		- Values: (20, 100)
# 	- Process --> imin: 24.0 - imax: 26.0
# 		- Values: (20, 100)
# 	- Process --> imin: 27.0 - imax: 29.0
# 		- Values: (20, 100)
# 	- Process --> imin: 30.0 - imax: 32.0
# 		- Values: (20, 100)
# 	- Process --> imin: 32.0 - imax: 34.0
# 		- Values: (20, 100)
# 	- Process --> imin: 36.0 - imax: 38.0
# 		- Values: (20, 100)
# 	- Process --> imin: 39.0 - imax: 41.0
# 		- Values: (20, 100)
# 	- Process --> imin: 41.0 - imax: 43.0
# 		- Values: (20, 100)
# 	- Process --> imin: 43.0 - imax: 45.0
# 		- Values: (20, 100)
# Now dataset is: (10, 20, 100)
# - Processing data: 1
# 	- Process --> imin: 4.5 - imax: 6.5
# 		- Values: (20, 100)
# 	- Process --> imin: 6.5 - imax: 8.5
# 		- Values: (20, 100)
# 	- Process --> imin: 14.5 - imax: 16.5
# 		- Values: (20, 100)
# 	- Process --> imin: 16.5 - imax: 18.5
# 		- Values: (20, 100)
# 	- Process --> imin: 18.5 - imax: 20.5
# 		- Values: (20, 100)
# 	- Process --> imin: 25.0 - imax: 27.0
# 		- Values: (20, 100)
# 	- Process --> imin: 27.0 - imax: 29.0
# 		- Values: (20, 100)
# 	- Process --> imin: 29.0 - imax: 31.0
# 		- Values: (20, 100)
# 	- Process --> imin: 30.3 - imax: 32.3
# 		- Values: (20, 100)
# 	- Process --> imin: 34.5 - imax: 36.5
# 		- Values: (20, 100)
# Now dataset is: (20, 20, 100)
# - Processing data: 2
# 	- Process --> imin: 3.3000000000000003 - imax: 5.3
# 		- Values: (20, 100)
# 	- Process --> imin: 6.0 - imax: 8.0
# 		- Values: (20, 100)
# 	- Process --> imin: 9.0 - imax: 11.0
# 		- Values: (20, 100)
# 	- Process --> imin: 15.0 - imax: 17.0
# 		- Values: (20, 100)
# 	- Process --> imin: 23.0 - imax: 25.0
# 		- Values: (20, 100)
# 	- Process --> imin: 29.0 - imax: 31.0
# 		- Values: (20, 100)
# 	- Process --> imin: 35.0 - imax: 37.0
# 		- Values: (20, 100)
# 	- Process --> imin: 47.0 - imax: 49.0
# 		- Values: (20, 100)
# 	- Process --> imin: 50.0 - imax: 52.0
# 		- Values: (20, 100)
# 	- Process --> imin: 57.0 - imax: 59.0
# 		- Values: (20, 100)
# Now dataset is: (30, 20, 100)
# - Processing data: 3
# 	- Process --> imin: 2.0 - imax: 4.0
# 		- Values: (20, 100)
# 	- Process --> imin: 4.0 - imax: 6.0
# 		- Values: (20, 100)
# 	- Process --> imin: 6.0 - imax: 8.0
# 		- Values: (20, 100)
# 	- Process --> imin: 12.700000000000001 - imax: 14.700000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 14.700000000000001 - imax: 16.7
# 		- Values: (20, 100)
# 	- Process --> imin: 21.1 - imax: 23.1
# 		- Values: (20, 100)
# 	- Process --> imin: 23.1 - imax: 25.1
# 		- Values: (20, 100)
# 	- Process --> imin: 35.2 - imax: 37.2
# 		- Values: (20, 100)
# 	- Process --> imin: 37.2 - imax: 39.2
# 		- Values: (20, 100)
# 	- Process --> imin: 40.2 - imax: 42.2
# 		- Values: (20, 100)
# Now dataset is: (40, 20, 100)
# - Processing data: 4
# 	- Process --> imin: 1.0 - imax: 3.0
# 		- Values: (20, 100)
# 	- Process --> imin: 3.0 - imax: 5.0
# 		- Values: (20, 100)
# 	- Process --> imin: 5.0 - imax: 7.0
# 		- Values: (20, 100)
# 	- Process --> imin: 7.0 - imax: 9.0
# 		- Values: (20, 100)
# 	- Process --> imin: 9.0 - imax: 11.0
# 		- Values: (20, 100)
# 	- Process --> imin: 11.0 - imax: 13.0
# 		- Values: (20, 100)
# 	- Process --> imin: 13.0 - imax: 15.0
# 		- Values: (20, 100)
# 	- Process --> imin: 15.0 - imax: 17.0
# 		- Values: (20, 100)
# 	- Process --> imin: 17.0 - imax: 19.0
# 		- Values: (20, 100)
# 	- Process --> imin: 25.0 - imax: 27.0
# 		- Values: (20, 100)
# Now dataset is: (50, 20, 100)
# - Processing data: 5
# 	- Process --> imin: 2.2 - imax: 4.2
# 		- Values: (20, 100)
# 	- Process --> imin: 8.0 - imax: 10.0
# 		- Values: (20, 100)
# 	- Process --> imin: 10.0 - imax: 12.0
# 		- Values: (20, 100)
# 	- Process --> imin: 12.0 - imax: 14.0
# 		- Values: (20, 100)
# 	- Process --> imin: 15.0 - imax: 17.0
# 		- Values: (20, 100)
# 	- Process --> imin: 19.0 - imax: 21.0
# 		- Values: (20, 100)
# 	- Process --> imin: 21.0 - imax: 23.0
# 		- Values: (20, 100)
# 	- Process --> imin: 23.0 - imax: 25.0
# 		- Values: (20, 100)
# 	- Process --> imin: 25.0 - imax: 27.0
# 		- Values: (20, 100)
# 	- Process --> imin: 27.0 - imax: 29.0
# 		- Values: (20, 100)
# Now dataset is: (60, 20, 100)
# - Processing data: 6
# 	- Process --> imin: 1.0 - imax: 3.0
# 		- Values: (20, 100)
# 	- Process --> imin: 3.0 - imax: 5.0
# 		- Values: (20, 100)
# 	- Process --> imin: 5.0 - imax: 7.0
# 		- Values: (20, 100)
# 	- Process --> imin: 7.0 - imax: 9.0
# 		- Values: (20, 100)
# 	- Process --> imin: 9.0 - imax: 11.0
# 		- Values: (20, 100)
# 	- Process --> imin: 11.0 - imax: 13.0
# 		- Values: (20, 100)
# 	- Process --> imin: 13.0 - imax: 15.0
# 		- Values: (20, 100)
# 	- Process --> imin: 15.0 - imax: 17.0
# 		- Values: (20, 100)
# 	- Process --> imin: 17.0 - imax: 19.0
# 		- Values: (20, 100)
# 	- Process --> imin: 24.0 - imax: 26.0
# 		- Values: (20, 100)
# Now dataset is: (70, 20, 100)
# - Processing data: 7
# 	- Process --> imin: 3.0 - imax: 5.0
# 		- Values: (20, 100)
# 	- Process --> imin: 10.3 - imax: 12.3
# 		- Values: (20, 100)
# 	- Process --> imin: 15.8 - imax: 17.8
# 		- Values: (20, 100)
# 	- Process --> imin: 22.8 - imax: 24.8
# 		- Values: (20, 100)
# 	- Process --> imin: 32.4 - imax: 34.400000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 82.4 - imax: 84.4
# 		- Values: (20, 100)
# 	- Process --> imin: 84.4 - imax: 86.4
# 		- Values: (20, 100)
# 	- Process --> imin: 92.0 - imax: 94.0
# 		- Values: (20, 100)
# 	- Process --> imin: 101.80000000000001 - imax: 103.80000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 103.80000000000001 - imax: 105.80000000000001
# 		- Values: (20, 100)
# Now dataset is: (80, 20, 100)
# - Processing data: 8
# 	- Process --> imin: 6.1000000000000005 - imax: 8.1
# 		- Values: (20, 100)
# 	- Process --> imin: 8.1 - imax: 10.100000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 10.8 - imax: 12.8
# 		- Values: (20, 100)
# 	- Process --> imin: 12.8 - imax: 14.8
# 		- Values: (20, 100)
# 	- Process --> imin: 14.8 - imax: 16.8
# 		- Values: (20, 100)
# 	- Process --> imin: 22.8 - imax: 24.8
# 		- Values: (20, 100)
# 	- Process --> imin: 32.300000000000004 - imax: 34.300000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 41.900000000000006 - imax: 43.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 48.7 - imax: 50.7
# 		- Values: (20, 100)
# 	- Process --> imin: 59.7 - imax: 61.7
# 		- Values: (20, 100)
# Now dataset is: (90, 20, 100)
# - Processing data: 9
# 	- Process --> imin: 2.2 - imax: 4.2
# 		- Values: (20, 100)
# 	- Process --> imin: 4.2 - imax: 6.2
# 		- Values: (20, 100)
# 	- Process --> imin: 30.8 - imax: 32.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 32.800000000000004 - imax: 34.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 40.300000000000004 - imax: 42.300000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 42.300000000000004 - imax: 44.300000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 58.50000000000001 - imax: 60.50000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 62.50000000000001 - imax: 64.5
# 		- Values: (20, 100)
# 	- Process --> imin: 87.2 - imax: 89.2
# 		- Values: (20, 100)
# 	- Process --> imin: 89.2 - imax: 91.2
# 		- Values: (20, 100)
# Now dataset is: (100, 20, 100)
# - Processing data: 10
# 	- Process --> imin: 3.9000000000000004 - imax: 5.9
# 		- Values: (20, 100)
# 	- Process --> imin: 5.9 - imax: 7.9
# 		- Values: (20, 100)
# 	- Process --> imin: 49.800000000000004 - imax: 51.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 51.800000000000004 - imax: 53.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 53.800000000000004 - imax: 55.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 63.300000000000004 - imax: 65.3
# 		- Values: (20, 100)
# 	- Process --> imin: 71.30000000000001 - imax: 73.30000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 83.30000000000001 - imax: 85.30000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 92.30000000000001 - imax: 94.30000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 101.80000000000001 - imax: 103.80000000000001
# 		- Values: (20, 100)
# Now dataset is: (110, 20, 100)
# - Processing data: 11
# 	- Process --> imin: 37.400000000000006 - imax: 39.400000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 49.800000000000004 - imax: 51.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 51.800000000000004 - imax: 53.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 58.2 - imax: 60.2
# 		- Values: (20, 100)
# 	- Process --> imin: 71.0 - imax: 73.0
# 		- Values: (20, 100)
# 	- Process --> imin: 78.80000000000001 - imax: 80.80000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 80.80000000000001 - imax: 82.80000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 86.30000000000001 - imax: 88.30000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 96.9 - imax: 98.9
# 		- Values: (20, 100)
# 	- Process --> imin: 98.60000000000001 - imax: 100.60000000000001
# 		- Values: (20, 100)
# Now dataset is: (120, 20, 100)
# - Processing data: 12
# 	- Process --> imin: 14.000000000000002 - imax: 16.0
# 		- Values: (20, 100)
# 	- Process --> imin: 26.0 - imax: 28.000000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 29.500000000000004 - imax: 31.500000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 32.5 - imax: 34.5
# 		- Values: (20, 100)
# 	- Process --> imin: 38.0 - imax: 40.0
# 		- Values: (20, 100)
# 	- Process --> imin: 40.0 - imax: 42.0
# 		- Values: (20, 100)
# 	- Process --> imin: 44.0 - imax: 46.0
# 		- Values: (20, 100)
# 	- Process --> imin: 47.0 - imax: 49.0
# 		- Values: (20, 100)
# 	- Process --> imin: 50.0 - imax: 52.0
# 		- Values: (20, 100)
# 	- Process --> imin: 131.0 - imax: 133.0
# 		- Values: (20, 100)
# Now dataset is: (130, 20, 100)
# - Processing data: 13
# 	- Process --> imin: 13.700000000000001 - imax: 15.700000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 15.700000000000001 - imax: 17.700000000000003
# 		- Values: (20, 100)
# 	- Process --> imin: 17.700000000000003 - imax: 19.700000000000003
# 		- Values: (20, 100)
# 	- Process --> imin: 24.6 - imax: 26.6
# 		- Values: (20, 100)
# 	- Process --> imin: 26.6 - imax: 28.6
# 		- Values: (20, 100)
# 	- Process --> imin: 32.9 - imax: 34.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 34.900000000000006 - imax: 36.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 45.900000000000006 - imax: 47.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 53.800000000000004 - imax: 55.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 55.800000000000004 - imax: 57.800000000000004
# 		- Values: (20, 100)
# Now dataset is: (140, 20, 100)
# - Processing data: 14
# 	- Process --> imin: 12.700000000000001 - imax: 14.700000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 26.1 - imax: 28.1
# 		- Values: (20, 100)
# 	- Process --> imin: 42.2 - imax: 44.2
# 		- Values: (20, 100)
# 	- Process --> imin: 44.2 - imax: 46.2
# 		- Values: (20, 100)
# 	- Process --> imin: 46.2 - imax: 48.2
# 		- Values: (20, 100)
# 	- Process --> imin: 49.7 - imax: 51.7
# 		- Values: (20, 100)
# 	- Process --> imin: 51.7 - imax: 53.7
# 		- Values: (20, 100)
# 	- Process --> imin: 69.4 - imax: 71.4
# 		- Values: (20, 100)
# 	- Process --> imin: 75.10000000000001 - imax: 77.10000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 78.10000000000001 - imax: 80.10000000000001
# 		- Values: (20, 100)
# Now dataset is: (150, 20, 100)
# - Processing data: 15
# 	- Process --> imin: 12.5 - imax: 14.500000000000002
# 		- Values: (20, 100)
# 	- Process --> imin: 14.500000000000002 - imax: 16.5
# 		- Values: (20, 100)
# 	- Process --> imin: 31.000000000000004 - imax: 33.0
# 		- Values: (20, 100)
# 	- Process --> imin: 35.800000000000004 - imax: 37.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 41.400000000000006 - imax: 43.400000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 43.400000000000006 - imax: 45.400000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 45.400000000000006 - imax: 47.400000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 82.2 - imax: 84.2
# 		- Values: (20, 100)
# 	- Process --> imin: 100.60000000000001 - imax: 102.60000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 113.00000000000001 - imax: 115.00000000000001
# 		- Values: (20, 100)
# Now dataset is: (160, 20, 100)
# - Processing data: 16
# 	- Process --> imin: 3.6 - imax: 5.6000000000000005
# 		- Values: (20, 100)
# 	- Process --> imin: 20.5 - imax: 22.5
# 		- Values: (20, 100)
# 	- Process --> imin: 30.1 - imax: 32.1
# 		- Values: (20, 100)
# 	- Process --> imin: 40.9 - imax: 42.9
# 		- Values: (20, 100)
# 	- Process --> imin: 45.1 - imax: 47.1
# 		- Values: (20, 100)
# 	- Process --> imin: 62.300000000000004 - imax: 64.3
# 		- Values: (20, 100)
# 	- Process --> imin: 63.300000000000004 - imax: 65.3
# 		- Values: (20, 100)
# 	- Process --> imin: 69.2 - imax: 71.2
# 		- Values: (20, 100)
# 	- Process --> imin: 71.2 - imax: 73.2
# 		- Values: (20, 100)
# 	- Process --> imin: 100.2 - imax: 102.2
# 		- Values: (20, 100)
# Now dataset is: (170, 20, 100)
# - Processing data: 17
# 	- Process --> imin: 5.1000000000000005 - imax: 7.1000000000000005
# 		- Values: (20, 100)
# 	- Process --> imin: 15.000000000000002 - imax: 17.0
# 		- Values: (20, 100)
# 	- Process --> imin: 22.8 - imax: 24.8
# 		- Values: (20, 100)
# 	- Process --> imin: 24.8 - imax: 26.8
# 		- Values: (20, 100)
# 	- Process --> imin: 32.9 - imax: 34.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 34.900000000000006 - imax: 36.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 43.0 - imax: 45.0
# 		- Values: (20, 100)
# 	- Process --> imin: 69.60000000000001 - imax: 71.60000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 81.0 - imax: 83.0
# 		- Values: (20, 100)
# 	- Process --> imin: 92.5 - imax: 94.5
# 		- Values: (20, 100)
# Now dataset is: (180, 20, 100)
# - Processing data: 18
# 	- Process --> imin: 5.9 - imax: 7.9
# 		- Values: (20, 100)
# 	- Process --> imin: 15.4 - imax: 17.400000000000002
# 		- Values: (20, 100)
# 	- Process --> imin: 21.700000000000003 - imax: 23.700000000000003
# 		- Values: (20, 100)
# 	- Process --> imin: 32.5 - imax: 34.5
# 		- Values: (20, 100)
# 	- Process --> imin: 41.900000000000006 - imax: 43.900000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 50.1 - imax: 52.1
# 		- Values: (20, 100)
# 	- Process --> imin: 61.00000000000001 - imax: 63.00000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 80.10000000000001 - imax: 82.10000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 89.5 - imax: 91.5
# 		- Values: (20, 100)
# 	- Process --> imin: 108.60000000000001 - imax: 110.60000000000001
# 		- Values: (20, 100)
# Now dataset is: (190, 20, 100)
# - Processing data: 19
# 	- Process --> imin: 5.2 - imax: 7.2
# 		- Values: (20, 100)
# 	- Process --> imin: 12.8 - imax: 14.8
# 		- Values: (20, 100)
# 	- Process --> imin: 22.6 - imax: 24.6
# 		- Values: (20, 100)
# 	- Process --> imin: 24.6 - imax: 26.6
# 		- Values: (20, 100)
# 	- Process --> imin: 33.800000000000004 - imax: 35.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 45.0 - imax: 47.0
# 		- Values: (20, 100)
# 	- Process --> imin: 49.400000000000006 - imax: 51.400000000000006
# 		- Values: (20, 100)
# 	- Process --> imin: 77.9 - imax: 79.9
# 		- Values: (20, 100)
# 	- Process --> imin: 116.60000000000001 - imax: 118.60000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 118.60000000000001 - imax: 120.60000000000001
# 		- Values: (20, 100)
# Now dataset is: (200, 20, 100)
# - Processing data: 20
# 	- Process --> imin: 612.2 - imax: 614.2
# 		- Values: (20, 100)
# 	- Process --> imin: 621.7 - imax: 623.7
# 		- Values: (20, 100)
# 	- Process --> imin: 626.5 - imax: 628.5
# 		- Values: (20, 100)
# 	- Process --> imin: 640.7 - imax: 642.7
# 		- Values: (20, 100)
# 	- Process --> imin: 662.1 - imax: 664.1
# 		- Values: (20, 100)
# 	- Process --> imin: 671.6 - imax: 673.6
# 		- Values: (20, 100)
# 	- Process --> imin: 681.1 - imax: 683.1
# 		- Values: (20, 100)
# 	- Process --> imin: 727.0 - imax: 729.0
# 		- Values: (20, 100)
# 	- Process --> imin: 737.0 - imax: 739.0
# 		- Values: (20, 100)
# 	- Process --> imin: 749.7 - imax: 751.7
# 		- Values: (20, 100)
# Now dataset is: (210, 20, 100)
# - Processing data: 21
# 	- Process --> imin: 46.0 - imax: 48.0
# 		- Values: (20, 100)
# 	- Process --> imin: 48.0 - imax: 50.0
# 		- Values: (20, 100)
# 	- Process --> imin: 50.0 - imax: 52.0
# 		- Values: (20, 100)
# 	- Process --> imin: 52.0 - imax: 54.0
# 		- Values: (20, 100)
# 	- Process --> imin: 61.0 - imax: 63.0
# 		- Values: (20, 100)
# 	- Process --> imin: 64.0 - imax: 66.0
# 		- Values: (20, 100)
# 	- Process --> imin: 73.0 - imax: 75.0
# 		- Values: (20, 100)
# 	- Process --> imin: 108.0 - imax: 110.0
# 		- Values: (20, 100)
# 	- Process --> imin: 475.0 - imax: 477.0
# 		- Values: (20, 100)
# 	- Process --> imin: 530.0 - imax: 532.0
# 		- Values: (20, 100)
# Now dataset is: (220, 20, 100)
# - Processing data: 22
# 	- Process --> imin: 194.0 - imax: 196.0
# 		- Values: (20, 100)
# 	- Process --> imin: 196.0 - imax: 198.0
# 		- Values: (20, 100)
# 	- Process --> imin: 198.0 - imax: 200.0
# 		- Values: (20, 100)
# 	- Process --> imin: 200.0 - imax: 202.0
# 		- Values: (20, 100)
# 	- Process --> imin: 203.0 - imax: 205.0
# 		- Values: (20, 100)
# 	- Process --> imin: 222.0 - imax: 224.0
# 		- Values: (20, 100)
# 	- Process --> imin: 224.0 - imax: 226.0
# 		- Values: (20, 100)
# 	- Process --> imin: 227.0 - imax: 229.0
# 		- Values: (20, 100)
# 	- Process --> imin: 267.0 - imax: 269.0
# 		- Values: (20, 100)
# 	- Process --> imin: 296.0 - imax: 298.0
# 		- Values: (20, 100)
# Now dataset is: (230, 20, 100)
# - Processing data: 23
# 	- Process --> imin: 115.0 - imax: 117.0
# 		- Values: (20, 100)
# 	- Process --> imin: 117.0 - imax: 119.0
# 		- Values: (20, 100)
# 	- Process --> imin: 119.0 - imax: 121.0
# 		- Values: (20, 100)
# 	- Process --> imin: 120.0 - imax: 122.0
# 		- Values: (20, 100)
# 	- Process --> imin: 125.0 - imax: 127.0
# 		- Values: (20, 100)
# 	- Process --> imin: 127.0 - imax: 129.0
# 		- Values: (20, 100)
# 	- Process --> imin: 134.0 - imax: 136.0
# 		- Values: (20, 100)
# 	- Process --> imin: 138.0 - imax: 140.0
# 		- Values: (20, 100)
# 	- Process --> imin: 141.0 - imax: 143.0
# 		- Values: (20, 100)
# 	- Process --> imin: 148.0 - imax: 150.0
# 		- Values: (20, 100)
# Now dataset is: (240, 20, 100)
# - Processing data: 24
# 	- Process --> imin: 10.0 - imax: 12.0
# 		- Values: (20, 100)
# 	- Process --> imin: 12.0 - imax: 14.0
# 		- Values: (20, 100)
# 	- Process --> imin: 14.0 - imax: 16.0
# 		- Values: (20, 100)
# 	- Process --> imin: 16.0 - imax: 18.0
# 		- Values: (20, 100)
# 	- Process --> imin: 16.0 - imax: 18.0
# 		- Values: (20, 100)
# 	- Process --> imin: 16.0 - imax: 18.0
# 		- Values: (20, 100)
# 	- Process --> imin: 33.0 - imax: 35.0
# 		- Values: (20, 100)
# 	- Process --> imin: 46.0 - imax: 48.0
# 		- Values: (20, 100)
# 	- Process --> imin: 49.0 - imax: 51.0
# 		- Values: (20, 100)
# 	- Process --> imin: 544.0 - imax: 546.0
# 		- Values: (20, 100)
# Now dataset is: (250, 20, 100)
# - Processing data: 25
# 	- Process --> imin: 127.0 - imax: 129.0
# 		- Values: (20, 100)
# 	- Process --> imin: 129.0 - imax: 131.0
# 		- Values: (20, 100)
# 	- Process --> imin: 181.0 - imax: 183.0
# 		- Values: (20, 100)
# 	- Process --> imin: 229.0 - imax: 231.0
# 		- Values: (20, 100)
# 	- Process --> imin: 277.0 - imax: 279.0
# 		- Values: (20, 100)
# 	- Process --> imin: 312.0 - imax: 314.0
# 		- Values: (20, 100)
# 	- Process --> imin: 476.0 - imax: 478.0
# 		- Values: (20, 100)
# 	- Process --> imin: 478.0 - imax: 480.0
# 		- Values: (20, 100)
# 	- Process --> imin: 482.0 - imax: 484.0
# 		- Values: (20, 100)
# 	- Process --> imin: 484.0 - imax: 486.0
# 		- Values: (20, 100)
# Now dataset is: (260, 20, 100)
# - Processing data: 26
# 	- Process --> imin: 72.0 - imax: 74.0
# 		- Values: (20, 100)
# 	- Process --> imin: 78.0 - imax: 80.0
# 		- Values: (20, 100)
# 	- Process --> imin: 90.0 - imax: 92.0
# 		- Values: (20, 100)
# 	- Process --> imin: 240.0 - imax: 242.0
# 		- Values: (20, 100)
# 	- Process --> imin: 258.0 - imax: 260.0
# 		- Values: (20, 100)
# 	- Process --> imin: 354.0 - imax: 356.0
# 		- Values: (20, 100)
# 	- Process --> imin: 459.0 - imax: 461.0
# 		- Values: (20, 100)
# 	- Process --> imin: 464.0 - imax: 466.0
# 		- Values: (20, 100)
# 	- Process --> imin: 466.0 - imax: 468.0
# 		- Values: (20, 100)
# 	- Process --> imin: 468.0 - imax: 470.0
# 		- Values: (20, 100)
# Now dataset is: (270, 20, 100)
# - Processing data: 27
# 	- Process --> imin: 234.0 - imax: 236.0
# 		- Values: (20, 100)
# 	- Process --> imin: 243.0 - imax: 245.0
# 		- Values: (20, 100)
# 	- Process --> imin: 314.0 - imax: 316.0
# 		- Values: (20, 100)
# 	- Process --> imin: 356.0 - imax: 358.0
# 		- Values: (20, 100)
# 	- Process --> imin: 446.0 - imax: 448.0
# 		- Values: (20, 100)
# 	- Process --> imin: 455.0 - imax: 457.0
# 		- Values: (20, 100)
# 	- Process --> imin: 411.0 - imax: 413.0
# 		- Values: (20, 100)
# 	- Process --> imin: 414.0 - imax: 416.0
# 		- Values: (20, 100)
# 	- Process --> imin: 416.0 - imax: 418.0
# 		- Values: (20, 100)
# 	- Process --> imin: 418.0 - imax: 420.0
# 		- Values: (20, 100)
# Now dataset is: (280, 20, 100)
# - Processing data: 28
# 	- Process --> imin: 64.0 - imax: 66.0
# 		- Values: (20, 100)
# 	- Process --> imin: 71.0 - imax: 73.0
# 		- Values: (20, 100)
# 	- Process --> imin: 74.0 - imax: 76.0
# 		- Values: (20, 100)
# 	- Process --> imin: 76.0 - imax: 78.0
# 		- Values: (20, 100)
# 	- Process --> imin: 88.0 - imax: 90.0
# 		- Values: (20, 100)
# 	- Process --> imin: 105.0 - imax: 107.0
# 		- Values: (20, 100)
# 	- Process --> imin: 111.0 - imax: 113.0
# 		- Values: (20, 100)
# 	- Process --> imin: 119.0 - imax: 121.0
# 		- Values: (20, 100)
# 	- Process --> imin: 130.0 - imax: 132.0
# 		- Values: (20, 100)
# 	- Process --> imin: 132.0 - imax: 134.0
# 		- Values: (20, 100)
# Now dataset is: (290, 20, 100)
# - Processing data: 29
# 	- Process --> imin: 198.0 - imax: 200.0
# 		- Values: (20, 100)
# 	- Process --> imin: 200.0 - imax: 202.0
# 		- Values: (20, 100)
# 	- Process --> imin: 202.0 - imax: 204.0
# 		- Values: (20, 100)
# 	- Process --> imin: 204.0 - imax: 206.0
# 		- Values: (20, 100)
# 	- Process --> imin: 219.0 - imax: 221.0
# 		- Values: (20, 100)
# 	- Process --> imin: 248.0 - imax: 250.0
# 		- Values: (20, 100)
# 	- Process --> imin: 312.0 - imax: 314.0
# 		- Values: (20, 100)
# 	- Process --> imin: 327.0 - imax: 329.0
# 		- Values: (20, 100)
# 	- Process --> imin: 336.0 - imax: 338.0
# 		- Values: (20, 100)
# 	- Process --> imin: 370.0 - imax: 372.0
# 		- Values: (20, 100)
# Now dataset is: (300, 20, 100)
# - Processing data: 30
# 	- Process --> imin: 429.0 - imax: 431.0
# 		- Values: (20, 100)
# 	- Process --> imin: 431.0 - imax: 433.0
# 		- Values: (20, 100)
# 	- Process --> imin: 433.0 - imax: 435.0
# 		- Values: (20, 100)
# 	- Process --> imin: 435.0 - imax: 437.0
# 		- Values: (20, 100)
# 	- Process --> imin: 493.0 - imax: 495.0
# 		- Values: (20, 100)
# 	- Process --> imin: 501.0 - imax: 503.0
# 		- Values: (20, 100)
# 	- Process --> imin: 511.0 - imax: 513.0
# 		- Values: (20, 100)
# 	- Process --> imin: 523.0 - imax: 525.0
# 		- Values: (20, 100)
# 	- Process --> imin: 538.0 - imax: 540.0
# 		- Values: (20, 100)
# 	- Process --> imin: 561.0 - imax: 563.0
# 		- Values: (20, 100)
# Now dataset is: (310, 20, 100)
# - Processing data: 31
# 	- Process --> imin: 80.0 - imax: 82.0
# 		- Values: (20, 100)
# 	- Process --> imin: 82.0 - imax: 84.0
# 		- Values: (20, 100)
# 	- Process --> imin: 84.0 - imax: 86.0
# 		- Values: (20, 100)
# 	- Process --> imin: 86.0 - imax: 88.0
# 		- Values: (20, 100)
# 	- Process --> imin: 102.0 - imax: 104.0
# 		- Values: (20, 100)
# 	- Process --> imin: 124.0 - imax: 126.0
# 		- Values: (20, 100)
# 	- Process --> imin: 148.0 - imax: 150.0
# 		- Values: (20, 100)
# 	- Process --> imin: 160.0 - imax: 162.0
# 		- Values: (20, 100)
# 	- Process --> imin: 174.0 - imax: 176.0
# 		- Values: (20, 100)
# 	- Process --> imin: 206.0 - imax: 208.0
# 		- Values: (20, 100)
# Now dataset is: (320, 20, 100)
# - Processing data: 32
# 	- Process --> imin: 141.0 - imax: 143.0
# 		- Values: (20, 100)
# 	- Process --> imin: 163.0 - imax: 165.0
# 		- Values: (20, 100)
# 	- Process --> imin: 176.0 - imax: 178.0
# 		- Values: (20, 100)
# 	- Process --> imin: 192.0 - imax: 194.0
# 		- Values: (20, 100)
# 	- Process --> imin: 194.0 - imax: 196.0
# 		- Values: (20, 100)
# 	- Process --> imin: 196.0 - imax: 198.0
# 		- Values: (20, 100)
# 	- Process --> imin: 198.0 - imax: 200.0
# 		- Values: (20, 100)
# 	- Process --> imin: 213.0 - imax: 215.0
# 		- Values: (20, 100)
# 	- Process --> imin: 224.0 - imax: 226.0
# 		- Values: (20, 100)
# 	- Process --> imin: 259.0 - imax: 261.0
# 		- Values: (20, 100)
# Now dataset is: (330, 20, 100)
# - Processing data: 33
# 	- Process --> imin: 485.0 - imax: 487.0
# 		- Values: (20, 100)
# 	- Process --> imin: 487.0 - imax: 489.0
# 		- Values: (20, 100)
# 	- Process --> imin: 489.0 - imax: 491.0
# 		- Values: (20, 100)
# 	- Process --> imin: 491.0 - imax: 493.0
# 		- Values: (20, 100)
# 	- Process --> imin: 507.0 - imax: 509.0
# 		- Values: (20, 100)
# 	- Process --> imin: 519.0 - imax: 521.0
# 		- Values: (20, 100)
# 	- Process --> imin: 541.0 - imax: 543.0
# 		- Values: (20, 100)
# 	- Process --> imin: 558.0 - imax: 560.0
# 		- Values: (20, 100)
# 	- Process --> imin: 564.0 - imax: 566.0
# 		- Values: (20, 100)
# 	- Process --> imin: 571.0 - imax: 573.0
# 		- Values: (20, 100)
# Now dataset is: (340, 20, 100)
# - Processing data: 34
# 	- Process --> imin: 15.0 - imax: 17.0
# 		- Values: (20, 100)
# 	- Process --> imin: 68.0 - imax: 70.0
# 		- Values: (20, 100)
# 	- Process --> imin: 91.0 - imax: 93.0
# 		- Values: (20, 100)
# 	- Process --> imin: 113.0 - imax: 115.0
# 		- Values: (20, 100)
# 	- Process --> imin: 286.0 - imax: 288.0
# 		- Values: (20, 100)
# 	- Process --> imin: 288.0 - imax: 290.0
# 		- Values: (20, 100)
# 	- Process --> imin: 290.0 - imax: 292.0
# 		- Values: (20, 100)
# 	- Process --> imin: 292.0 - imax: 294.0
# 		- Values: (20, 100)
# 	- Process --> imin: 316.0 - imax: 318.0
# 		- Values: (20, 100)
# 	- Process --> imin: 547.0 - imax: 549.0
# 		- Values: (20, 100)
# Now dataset is: (350, 20, 100)
# - Processing data: 35
# 	- Process --> imin: 145.0 - imax: 147.0
# 		- Values: (20, 100)
# 	- Process --> imin: 147.0 - imax: 149.0
# 		- Values: (20, 100)
# 	- Process --> imin: 149.0 - imax: 151.0
# 		- Values: (20, 100)
# 	- Process --> imin: 151.0 - imax: 153.0
# 		- Values: (20, 100)
# 	- Process --> imin: 183.0 - imax: 185.0
# 		- Values: (20, 100)
# 	- Process --> imin: 210.0 - imax: 212.0
# 		- Values: (20, 100)
# 	- Process --> imin: 254.0 - imax: 256.0
# 		- Values: (20, 100)
# 	- Process --> imin: 305.0 - imax: 307.0
# 		- Values: (20, 100)
# 	- Process --> imin: 366.0 - imax: 368.0
# 		- Values: (20, 100)
# 	- Process --> imin: 427.0 - imax: 429.0
# 		- Values: (20, 100)
# Now dataset is: (360, 20, 100)
# - Processing data: 36
# 	- Process --> imin: 51.0 - imax: 53.0
# 		- Values: (20, 100)
# 	- Process --> imin: 97.0 - imax: 99.0
# 		- Values: (20, 100)
# 	- Process --> imin: 132.0 - imax: 134.0
# 		- Values: (20, 100)
# 	- Process --> imin: 244.0 - imax: 246.0
# 		- Values: (20, 100)
# 	- Process --> imin: 386.0 - imax: 388.0
# 		- Values: (20, 100)
# 	- Process --> imin: 470.0 - imax: 472.0
# 		- Values: (20, 100)
# 	- Process --> imin: 716.0 - imax: 718.0
# 		- Values: (20, 100)
# 	- Process --> imin: 718.0 - imax: 720.0
# 		- Values: (20, 100)
# 	- Process --> imin: 720.0 - imax: 722.0
# 		- Values: (20, 100)
# 	- Process --> imin: 722.0 - imax: 724.0
# 		- Values: (20, 100)
# Now dataset is: (370, 20, 100)
# - Processing data: 37
# 	- Process --> imin: 65.0 - imax: 67.0
# 		- Values: (20, 100)
# 	- Process --> imin: 151.0 - imax: 153.0
# 		- Values: (20, 100)
# 	- Process --> imin: 191.0 - imax: 193.0
# 		- Values: (20, 100)
# 	- Process --> imin: 231.0 - imax: 233.0
# 		- Values: (20, 100)
# 	- Process --> imin: 249.0 - imax: 251.0
# 		- Values: (20, 100)
# 	- Process --> imin: 394.0 - imax: 396.0
# 		- Values: (20, 100)
# 	- Process --> imin: 396.0 - imax: 398.0
# 		- Values: (20, 100)
# 	- Process --> imin: 398.0 - imax: 400.0
# 		- Values: (20, 100)
# 	- Process --> imin: 400.0 - imax: 402.0
# 		- Values: (20, 100)
# 	- Process --> imin: 477.0 - imax: 479.0
# 		- Values: (20, 100)
# Now dataset is: (380, 20, 100)
# - Processing data: 38
# 	- Process --> imin: 174.0 - imax: 176.0
# 		- Values: (20, 100)
# 	- Process --> imin: 246.0 - imax: 248.0
# 		- Values: (20, 100)
# 	- Process --> imin: 297.0 - imax: 299.0
# 		- Values: (20, 100)
# 	- Process --> imin: 315.0 - imax: 317.0
# 		- Values: (20, 100)
# 	- Process --> imin: 414.0 - imax: 416.0
# 		- Values: (20, 100)
# 	- Process --> imin: 450.0 - imax: 452.0
# 		- Values: (20, 100)
# 	- Process --> imin: 578.0 - imax: 580.0
# 		- Values: (20, 100)
# 	- Process --> imin: 580.0 - imax: 582.0
# 		- Values: (20, 100)
# 	- Process --> imin: 582.0 - imax: 584.0
# 		- Values: (20, 100)
# 	- Process --> imin: 584.0 - imax: 586.0
# 		- Values: (20, 100)
# Now dataset is: (390, 20, 100)
# - Processing data: 39
# 	- Process --> imin: 71.0 - imax: 73.0
# 		- Values: (20, 100)
# 	- Process --> imin: 177.0 - imax: 179.0
# 		- Values: (20, 100)
# 	- Process --> imin: 218.0 - imax: 220.0
# 		- Values: (20, 100)
# 	- Process --> imin: 248.0 - imax: 250.0
# 		- Values: (20, 100)
# 	- Process --> imin: 258.0 - imax: 260.0
# 		- Values: (20, 100)
# 	- Process --> imin: 357.0 - imax: 359.0
# 		- Values: (20, 100)
# 	- Process --> imin: 595.0 - imax: 597.0
# 		- Values: (20, 100)
# 	- Process --> imin: 597.0 - imax: 599.0
# 		- Values: (20, 100)
# 	- Process --> imin: 599.0 - imax: 601.0
# 		- Values: (20, 100)
# 	- Process --> imin: 601.0 - imax: 603.0
# 		- Values: (20, 100)
# Now dataset is: (400, 20, 100)
# - Processing data: 40
# 	- Process --> imin: 25.0 - imax: 27.0
# 		- Values: (20, 100)
# 	- Process --> imin: 38.0 - imax: 40.0
# 		- Values: (20, 100)
# 	- Process --> imin: 81.0 - imax: 83.0
# 		- Values: (20, 100)
# 	- Process --> imin: 92.0 - imax: 94.0
# 		- Values: (20, 100)
# 	- Process --> imin: 123.0 - imax: 125.0
# 		- Values: (20, 100)
# 	- Process --> imin: 143.0 - imax: 145.0
# 		- Values: (20, 100)
# 	- Process --> imin: 216.0 - imax: 218.0
# 		- Values: (20, 100)
# 	- Process --> imin: 253.0 - imax: 255.0
# 		- Values: (20, 100)
# 	- Process --> imin: 341.0 - imax: 343.0
# 		- Values: (20, 100)
# 	- Process --> imin: 347.0 - imax: 349.0
# 		- Values: (20, 100)
# Now dataset is: (410, 20, 100)
# - Processing data: 41
# 	- Process --> imin: 193.0 - imax: 195.0
# 		- Values: (20, 100)
# 	- Process --> imin: 205.0 - imax: 207.0
# 		- Values: (20, 100)
# 	- Process --> imin: 260.0 - imax: 262.0
# 		- Values: (20, 100)
# 	- Process --> imin: 294.0 - imax: 296.0
# 		- Values: (20, 100)
# 	- Process --> imin: 316.0 - imax: 318.0
# 		- Values: (20, 100)
# 	- Process --> imin: 338.0 - imax: 340.0
# 		- Values: (20, 100)
# 	- Process --> imin: 367.0 - imax: 369.0
# 		- Values: (20, 100)
# 	- Process --> imin: 373.0 - imax: 375.0
# 		- Values: (20, 100)
# 	- Process --> imin: 412.0 - imax: 414.0
# 		- Values: (20, 100)
# 	- Process --> imin: 426.0 - imax: 428.0
# 		- Values: (20, 100)
# Now dataset is: (420, 20, 100)
# (420, 20, 100)

# %%
## Junta os sinais considerando a quantidade de hz e quantidade de segundos
signals_brain_death, labels_brain_death = get_signals_for_interval(dataset_ome, 1, seconds=1)
signals_brain_death.shape
# Out:
# - Processing data: 0
# 	- Process --> imin: 13.0 - imax: 15.0
# 		- Values: (20, 100)
# 	- Process --> imin: 20.0 - imax: 22.0
# 		- Values: (20, 100)
# 	- Process --> imin: 30.0 - imax: 32.0
# 		- Values: (20, 100)
# 	- Process --> imin: 41.0 - imax: 43.0
# 		- Values: (20, 100)
# 	- Process --> imin: 51.0 - imax: 53.0
# 		- Values: (20, 100)
# 	- Process --> imin: 59.0 - imax: 61.0
# 		- Values: (20, 100)
# 	- Process --> imin: 66.0 - imax: 68.0
# 		- Values: (20, 100)
# 	- Process --> imin: 72.0 - imax: 74.0
# 		- Values: (20, 100)
# 	- Process --> imin: 76.0 - imax: 78.0
# 		- Values: (20, 100)
# 	- Process --> imin: 80.0 - imax: 82.0
# 		- Values: (20, 100)
# Now dataset is: (10, 20, 100)
# - Processing data: 1
# 	- Process --> imin: 10.0 - imax: 12.0
# 		- Values: (20, 100)
# 	- Process --> imin: 13.8 - imax: 15.8
# 		- Values: (20, 100)
# 	- Process --> imin: 25.0 - imax: 27.0
# 		- Values: (20, 100)
# 	- Process --> imin: 27.0 - imax: 29.000000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 31.8 - imax: 33.800000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 61.300000000000004 - imax: 63.300000000000004
# 		- Values: (20, 100)
# 	- Process --> imin: 72.10000000000001 - imax: 74.10000000000001
# 		- Values: (20, 100)
# 	- Process --> imin: 80.2 - imax: 82.2
# 		- Values: (20, 100)
# 	- Process --> imin: 92.2 - imax: 94.2
# 		- Values: (20, 100)
# 	- Process --> imin: 109.5 - imax: 111.50000000000001
# 		- Values: (20, 100)
# Now dataset is: (20, 20, 100)
# - Processing data: 2
# 	- Process --> imin: 24.0 - imax: 26.0
# 		- Values: (20, 100)
# 	- Process --> imin: 47.0 - imax: 49.0
# 		- Values: (20, 100)
# 	- Process --> imin: 51.0 - imax: 53.0
# 		- Values: (20, 100)
# 	- Process --> imin: 63.0 - imax: 65.0
# 		- Values: (20, 100)
# 	- Process --> imin: 87.0 - imax: 89.0
# 		- Values: (20, 100)
# 	- Process --> imin: 99.0 - imax: 101.0
# 		- Values: (20, 100)
# 	- Process --> imin: 108.0 - imax: 110.0
# 		- Values: (20, 100)
# 	- Process --> imin: 135.0 - imax: 137.0
# 		- Values: (20, 100)
# 	- Process --> imin: 153.0 - imax: 155.0
# 		- Values: (20, 100)
# 	- Process --> imin: 170.0 - imax: 172.0
# 		- Values: (20, 100)
# Now dataset is: (30, 20, 100)
# - Processing data: 3
# 	- Process --> imin: 109.0 - imax: 111.0
# 		- Values: (20, 100)
# 	- Process --> imin: 111.0 - imax: 113.0
# 		- Values: (20, 100)
# 	- Process --> imin: 113.0 - imax: 115.0
# 		- Values: (20, 100)
# 	- Process --> imin: 115.0 - imax: 117.0
# 		- Values: (20, 100)
# 	- Process --> imin: 118.0 - imax: 120.0
# 		- Values: (20, 100)
# 	- Process --> imin: 120.0 - imax: 122.0
# 		- Values: (20, 100)
# 	- Process --> imin: 134.0 - imax: 136.0
# 		- Values: (20, 100)
# 	- Process --> imin: 143.0 - imax: 145.0
# 		- Values: (20, 100)
# 	- Process --> imin: 161.0 - imax: 163.0
# 		- Values: (20, 100)
# 	- Process --> imin: 165.0 - imax: 167.0
# 		- Values: (20, 100)
# Now dataset is: (40, 20, 100)
# - Processing data: 4
# 	- Process --> imin: 748.0 - imax: 750.0
# 		- Values: (20, 100)
# 	- Process --> imin: 750.0 - imax: 752.0
# 		- Values: (20, 100)
# 	- Process --> imin: 752.0 - imax: 754.0
# 		- Values: (20, 100)
# 	- Process --> imin: 754.0 - imax: 756.0
# 		- Values: (20, 100)
# 	- Process --> imin: 756.0 - imax: 758.0
# 		- Values: (20, 100)
# 	- Process --> imin: 758.0 - imax: 760.0
# 		- Values: (20, 100)
# 	- Process --> imin: 762.0 - imax: 764.0
# 		- Values: (20, 100)
# 	- Process --> imin: 769.0 - imax: 771.0
# 		- Values: (20, 100)
# 	- Process --> imin: 776.0 - imax: 778.0
# 		- Values: (20, 100)
# 	- Process --> imin: 793.0 - imax: 795.0
# 		- Values: (20, 100)
# Now dataset is: (50, 20, 100)
# - Processing data: 5
# 	- Process --> imin: 236.0 - imax: 238.0
# 		- Values: (20, 100)
# 	- Process --> imin: 238.0 - imax: 240.0
# 		- Values: (20, 100)
# 	- Process --> imin: 245.0 - imax: 247.0
# 		- Values: (20, 100)
# 	- Process --> imin: 247.0 - imax: 249.0
# 		- Values: (20, 100)
# 	- Process --> imin: 266.0 - imax: 268.0
# 		- Values: (20, 100)
# 	- Process --> imin: 313.0 - imax: 315.0
# 		- Values: (20, 100)
# 	- Process --> imin: 366.0 - imax: 368.0
# 		- Values: (20, 100)
# 	- Process --> imin: 381.0 - imax: 383.0
# 		- Values: (20, 100)
# 	- Process --> imin: 507.0 - imax: 509.0
# 		- Values: (20, 100)
# 	- Process --> imin: 569.0 - imax: 571.0
# 		- Values: (20, 100)
# Now dataset is: (60, 20, 100)
# - Processing data: 6
# 	- Process --> imin: 944.0 - imax: 946.0
# 		- Values: (20, 100)
# 	- Process --> imin: 971.0 - imax: 973.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1043.0 - imax: 1045.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1064.0 - imax: 1066.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1101.0 - imax: 1103.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1116.0 - imax: 1118.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1128.0 - imax: 1130.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1130.0 - imax: 1132.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1140.0 - imax: 1142.0
# 		- Values: (20, 100)
# 	- Process --> imin: 1142.0 - imax: 1144.0
# 		- Values: (20, 100)
# Now dataset is: (70, 20, 100)
# - Processing data: 7
# 	- Process --> imin: 593.0 - imax: 595.0
# 		- Values: (20, 100)
# 	- Process --> imin: 595.0 - imax: 597.0
# 		- Values: (20, 100)
# 	- Process --> imin: 597.0 - imax: 599.0
# 		- Values: (20, 100)
# 	- Process --> imin: 601.0 - imax: 603.0
# 		- Values: (20, 100)
# 	- Process --> imin: 603.0 - imax: 605.0
# 		- Values: (20, 100)
# 	- Process --> imin: 628.0 - imax: 630.0
# 		- Values: (20, 100)
# 	- Process --> imin: 635.0 - imax: 637.0
# 		- Values: (20, 100)
# 	- Process --> imin: 662.0 - imax: 664.0
# 		- Values: (20, 100)
# 	- Process --> imin: 712.0 - imax: 714.0
# 		- Values: (20, 100)
# 	- Process --> imin: 737.0 - imax: 739.0
# 		- Values: (20, 100)
# Now dataset is: (80, 20, 100)
# - Processing data: 8
# 	- Process --> imin: 636.0 - imax: 638.0
# 		- Values: (20, 100)
# 	- Process --> imin: 638.0 - imax: 640.0
# 		- Values: (20, 100)
# 	- Process --> imin: 640.0 - imax: 642.0
# 		- Values: (20, 100)
# 	- Process --> imin: 642.0 - imax: 644.0
# 		- Values: (20, 100)
# 	- Process --> imin: 644.0 - imax: 646.0
# 		- Values: (20, 100)
# 	- Process --> imin: 683.0 - imax: 685.0
# 		- Values: (20, 100)
# 	- Process --> imin: 688.0 - imax: 690.0
# 		- Values: (20, 100)
# 	- Process --> imin: 695.0 - imax: 697.0
# 		- Values: (20, 100)
# 	- Process --> imin: 736.0 - imax: 738.0
# 		- Values: (20, 100)
# 	- Process --> imin: 743.0 - imax: 745.0
# 		- Values: (20, 100)
# Now dataset is: (90, 20, 100)
# - Processing data: 9
# 	- Process --> imin: 32.0 - imax: 34.0
# 		- Values: (20, 100)
# 	- Process --> imin: 34.0 - imax: 36.0
# 		- Values: (20, 100)
# 	- Process --> imin: 36.0 - imax: 38.0
# 		- Values: (20, 100)
# 	- Process --> imin: 38.0 - imax: 40.0
# 		- Values: (20, 100)
# 	- Process --> imin: 46.0 - imax: 48.0
# 		- Values: (20, 100)
# 	- Process --> imin: 60.0 - imax: 62.0
# 		- Values: (20, 100)
# 	- Process --> imin: 99.0 - imax: 101.0
# 		- Values: (20, 100)
# 	- Process --> imin: 125.0 - imax: 127.0
# 		- Values: (20, 100)
# 	- Process --> imin: 165.0 - imax: 167.0
# 		- Values: (20, 100)
# 	- Process --> imin: 181.0 - imax: 183.0
# 		- Values: (20, 100)
# Now dataset is: (100, 20, 100)
# - Processing data: 10
# 	- Process --> imin: 1.0 - imax: 3.0
# 		- Values: (20, 100)
# 	- Process --> imin: 3.0 - imax: 5.0
# 		- Values: (20, 100)
# 	- Process --> imin: 5.0 - imax: 7.0
# 		- Values: (20, 100)
# 	- Process --> imin: 7.0 - imax: 9.0
# 		- Values: (20, 100)
# 	- Process --> imin: 22.0 - imax: 24.0
# 		- Values: (20, 100)
# 	- Process --> imin: 27.0 - imax: 29.0
# 		- Values: (20, 100)
# 	- Process --> imin: 44.0 - imax: 46.0
# 		- Values: (20, 100)
# 	- Process --> imin: 64.0 - imax: 66.0
# 		- Values: (20, 100)
# 	- Process --> imin: 75.0 - imax: 77.0
# 		- Values: (20, 100)
# 	- Process --> imin: 98.0 - imax: 100.0
# 		- Values: (20, 100)
# Now dataset is: (110, 20, 100)
# - Processing data: 11
# 	- Process --> imin: 174.0 - imax: 176.0
# 		- Values: (20, 100)
# 	- Process --> imin: 176.0 - imax: 178.0
# 		- Values: (20, 100)
# 	- Process --> imin: 178.0 - imax: 180.0
# 		- Values: (20, 100)
# 	- Process --> imin: 180.0 - imax: 182.0
# 		- Values: (20, 100)
# 	- Process --> imin: 190.0 - imax: 192.0
# 		- Values: (20, 100)
# 	- Process --> imin: 276.0 - imax: 278.0
# 		- Values: (20, 100)
# 	- Process --> imin: 323.0 - imax: 325.0
# 		- Values: (20, 100)
# 	- Process --> imin: 390.0 - imax: 392.0
# 		- Values: (20, 100)
# 	- Process --> imin: 410.0 - imax: 412.0
# 		- Values: (20, 100)
# 	- Process --> imin: 563.0 - imax: 565.0
# 		- Values: (20, 100)
# Now dataset is: (120, 20, 100)
# - Processing data: 12
# 	- Process --> imin: 48.0 - imax: 50.0
# 		- Values: (20, 100)
# 	- Process --> imin: 50.0 - imax: 52.0
# 		- Values: (20, 100)
# 	- Process --> imin: 52.0 - imax: 54.0
# 		- Values: (20, 100)
# 	- Process --> imin: 54.0 - imax: 56.0
# 		- Values: (20, 100)
# 	- Process --> imin: 93.0 - imax: 95.0
# 		- Values: (20, 100)
# 	- Process --> imin: 144.0 - imax: 146.0
# 		- Values: (20, 100)
# 	- Process --> imin: 183.0 - imax: 185.0
# 		- Values: (20, 100)
# 	- Process --> imin: 300.0 - imax: 302.0
# 		- Values: (20, 100)
# 	- Process --> imin: 446.0 - imax: 448.0
# 		- Values: (20, 100)
# 	- Process --> imin: 459.0 - imax: 461.0
# 		- Values: (20, 100)
# Now dataset is: (130, 20, 100)
# - Processing data: 13
# 	- Process --> imin: 56.0 - imax: 58.0
# 		- Values: (20, 100)
# 	- Process --> imin: 244.0 - imax: 246.0
# 		- Values: (20, 100)
# 	- Process --> imin: 277.0 - imax: 279.0
# 		- Values: (20, 100)
# 	- Process --> imin: 343.0 - imax: 345.0
# 		- Values: (20, 100)
# 	- Process --> imin: 368.0 - imax: 370.0
# 		- Values: (20, 100)
# 	- Process --> imin: 414.0 - imax: 416.0
# 		- Values: (20, 100)
# 	- Process --> imin: 445.0 - imax: 447.0
# 		- Values: (20, 100)
# 	- Process --> imin: 447.0 - imax: 449.0
# 		- Values: (20, 100)
# 	- Process --> imin: 449.0 - imax: 451.0
# 		- Values: (20, 100)
# 	- Process --> imin: 451.0 - imax: 453.0
# 		- Values: (20, 100)
# Now dataset is: (140, 20, 100)
# - Processing data: 14
# 	- Process --> imin: 65.0 - imax: 67.0
# 		- Values: (20, 100)
# 	- Process --> imin: 67.0 - imax: 69.0
# 		- Values: (20, 100)
# 	- Process --> imin: 69.0 - imax: 71.0
# 		- Values: (20, 100)
# 	- Process --> imin: 71.0 - imax: 73.0
# 		- Values: (20, 100)
# 	- Process --> imin: 95.0 - imax: 97.0
# 		- Values: (20, 100)
# 	- Process --> imin: 132.0 - imax: 134.0
# 		- Values: (20, 100)
# 	- Process --> imin: 203.0 - imax: 205.0
# 		- Values: (20, 100)
# 	- Process --> imin: 290.0 - imax: 292.0
# 		- Values: (20, 100)
# 	- Process --> imin: 359.0 - imax: 361.0
# 		- Values: (20, 100)
# 	- Process --> imin: 482.0 - imax: 484.0
# 		- Values: (20, 100)
# Now dataset is: (150, 20, 100)
# (150, 20, 100)

# %%
## Faz o agrupamento das duas classes ALIVE e BRAIN_DEATH
signals_concat = np.concatenate([signals_alive, signals_brain_death])
labels_concat = np.concatenate([labels_alive, labels_brain_death])

# %%
signals_concat.shape
# Out:
# (570, 20, 100)

# %%
import random

# %%
def suffle_list(x, y):
    # Combina as listas em uma lista de pares
    pares = list(zip(x, y))

    # Embaralha a lista de pares
    random.shuffle(pares)
    
    return zip(*pares)

# %%
signals_concat, labels_concat = suffle_list(signals_concat, labels_concat)

# %%
signals_concat = np.asarray(signals_concat)
labels_concat = np.asarray(labels_concat)

# %%
# Dividir os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(signals_concat, labels_concat, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder
# Criar instância do OneHotEncoder
onehotencoder = OneHotEncoder()

# Aplicar o One Hot Encoder nos dados
y_train = onehotencoder.fit_transform(np.array(y_train).reshape(-1, 1)).toarray()
y_test = onehotencoder.transform(np.array(y_test).reshape(-1, 1)).toarray()

# %%
train_X_normalized = X_train[:, :, :-1] #scaler.fit_transform()
train_Y_normalized = X_train[:, :, 1:] #scaler.fit_transform()

test_X_normalized = X_test[:, :, :-1] #scaler.fit_transform()
test_Y_normalized = X_test[:, :, 1:] #scaler.fit_transform()

train_X_normalized = train_X_normalized.reshape((train_X_normalized.shape[0], -1))
train_Y_normalized = train_Y_normalized.reshape((train_Y_normalized.shape[0], -1))

test_X_normalized = test_X_normalized.reshape((test_X_normalized.shape[0], -1))
test_Y_normalized = test_Y_normalized.reshape((test_Y_normalized.shape[0], -1))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
train_X_normalized = np.transpose(X_train, (0,2,1)).reshape((X_train.shape[0], -1))#[:, :-1]
train_Y_normalized = np.transpose(X_train, (0,2,1)).reshape((X_train.shape[0], -1))#[:, 1:]

test_X_normalized = np.transpose(X_test, (0,2,1)).reshape((X_test.shape[0], -1))#[:, :-1]
test_Y_normalized = np.transpose(X_test, (0,2,1)).reshape((X_test.shape[0], -1))#[:, 1:]

# %%
np.transpose(X_train, (0,2,1)).shape
# Out:
# (456, 100, 20)

# %%
train_Y_normalized.shape
# Out:
# (456, 2000)

# %% [markdown]
# ## Cria arquitetura para otimização da ESN - NN

# %%
template_architecture = {
        'esn': {
            'reservoir_size': random.randint(10, 4000),
            'spectral_radius': random.uniform(.1, 1),
            'sparsity': random.uniform(.1, 1)
        },
        'nn': {
            'size': random.randint(1, 10),
            'units': lambda nn_size: random.sample(range(1,1000), nn_size),
            'activations': lambda nn_size: random.choices(['relu', 'sigmoid', 'softmax'], k=nn_size)
        }
    }

# %%
template_architecture
# Out:
# {'esn': {'reservoir_size': 1807,
#   'spectral_radius': 0.3857098512515069,
#   'sparsity': 0.19951162302477451},
#  'nn': {'size': 9,
#   'units': <function __main__.<lambda>(nn_size)>,
#   'activations': <function __main__.<lambda>(nn_size)>}}

# %%
def create_template():

    template_architecture = {
        'esn': {
            'reservoir_size': random.randint(10, 4000),
            'spectral_radius': random.uniform(.1, 1),
            'sparsity': random.uniform(.1, 1)
        },
        'nn': {
            'size': random.randint(1, 10),
            'units': lambda nn_size: random.sample(range(1,1000), nn_size),
            'activations': lambda nn_size: random.choices(['relu', 'sigmoid', 'softmax'], k=nn_size)
        }
    }
    
    # Obtendo os valores de units e activations
    nn_size = template_architecture['nn']['size']
    units = template_architecture['nn']['units'](nn_size)
    activations = template_architecture['nn']['activations'](nn_size)
    
    # Atribuindo os valores obtidos a um novo objeto
    template_architecture['nn']['units'] = units
    template_architecture['nn']['activations'] = activations

    return template_architecture

# %%
def bin_array_to_dec(bin_array):
    return int(''.join([str(value) for value in list(bin_array)]), 2)

# %% [markdown]
# ### Montagem da fita genética do modelo

# %%
## Objeto que define os tamanhos máximos da de cada atributo na fita genética
max_range_architecture = {
    'esn': {
        'reservoir_size': 256,
#        'spectral_radius': 100,
#        'sparsity': 100
    },
        'nn': {
        'units1': 500,
        'activations1': 1,
        'units2': 255,
        'activations2': 1,
        'units3': 255,
        'activations3': 1,
        'units4': 120,
        'activations4': 1,
        # 'units5': 1000,
        # 'activations5': 1,
        # 'units6': 1000,
        # 'activations6': 1,
        # 'units7': 1000,
        # 'activations7': 1,
#        'loss': 'binary_crossentropy',
#        'optimizer': 'adam'
    }
}
max_size_hidden_nn = 7

# %%
## Cria um objeto que define o tamanho binário da presença de cada parametro na fita genética.
max_range_architecture_binary = {}
max_units_architecture_binary = {}
length_genetic_tape = 0
def recursive_loop(obj, key_parents=None):
    global max_units_architecture_binary, length_genetic_tape,max_size_hidden_nn, max_range_architecture_binary
    if isinstance(obj, dict):
        for key, value in obj.items():
            recursive_loop(value, '{}-{}'.format('' if key_parents == None else key_parents, key))
    else:   
        binary = bin(obj)
        # if 'nn' in key_parents: 
        #     max_binary = ([1]* len(binary[2:])) * max_size_hidden_nn
        #     space_on_tape = (len(binary[2:]) * max_size_hidden_nn) 
        #     length_genetic_tape += space_on_tape
        # else:
        max_binary = ([1]* len(binary[2:]))
        space_on_tape = len(binary[2:])
        length_genetic_tape += space_on_tape
            
        max_units_architecture_binary[key_parents] = space_on_tape
        max_range_architecture_binary[key_parents] = bin_array_to_dec(max_binary)

# %%
recursive_loop(max_range_architecture)

# %%
max_units_architecture_binary
# Out:
# {'-esn-reservoir_size': 9,
#  '-nn-units1': 9,
#  '-nn-activations1': 1,
#  '-nn-units2': 8,
#  '-nn-activations2': 1,
#  '-nn-units3': 8,
#  '-nn-activations3': 1,
#  '-nn-units4': 7,
#  '-nn-activations4': 1}

# %%
def get_obj_of_position_params_tape(max_units_architecture_binary, length_genetic_tape):
    positions_tape = range(length_genetic_tape)
    obj_position = {}
    position_selected = []
    
    for key, value in max_units_architecture_binary.items():
        position = random.sample([x for x in positions_tape if x not in position_selected], value)
        position_selected += position
        obj_position[key] = position
    return obj_position

# %%
## Definições
map_genetic_tape = get_obj_of_position_params_tape(max_units_architecture_binary, length_genetic_tape)
pop_size = 50
pop_random_perc = .04
generation = 200
n_parents_survive = 4
n_reinsertion = 40
inputs_size = train_X_normalized.shape[1]

max_validation = 1
reservoir_size = bin_array_to_dec([1]*max_units_architecture_binary['-esn-reservoir_size'])
units = [reservoir_size] + [bin_array_to_dec([1]*value) for key, value in max_units_architecture_binary.items() if 'units' in key] + [2]
max_units = sum([h1 * h2 for h1, h2 in zip(units[:-1], units[1:])])
max_reservoir_size = (inputs_size * reservoir_size) + (reservoir_size**2)

#data_population = pd.DataFrame()

# %%
# def init_population(pop_size):
#     global length_genetic_tape
    
#     genetic_tape_population = [[random.randint(0, 100) for value in range(length_genetic_tape)] for value in range(pop_size)]
#     genetic_tape_population = (np.asarray(genetic_tape_population) <= 10) * 1

#     return np.asarray(genetic_tape_population)

# %%
def init_population(pop_size):
    global length_genetic_tape
    
    genetic_tape_population = [[random.randint(0, 1) for value in range(length_genetic_tape)] for value in range(pop_size)]

    return np.asarray(genetic_tape_population)

# %%
def build_esn_nn_with_genetic_tape(genetic_tape):
    global map_genetic_tape, max_range_architecture_binary, inputs_size
    
    ## Constrói a ESN.
    reservoir_size = bin_array_to_dec(genetic_tape[map_genetic_tape['-esn-reservoir_size']])
    outputs = 1
    spectral_radius = .8#(bin_array_to_dec(genetic_tape[map_genetic_tape['-esn-spectral_radius']]) / max_range_architecture_binary['-esn-spectral_radius'])
    sparsity = 0#(bin_array_to_dec(genetic_tape[map_genetic_tape['-esn-sparsity']]) / max_range_architecture_binary['-esn-sparsity'])

    if reservoir_size<=0:
        reservoir_size = 1
    
    esn = ESN(n_inputs=inputs_size, # Número de eletrodos
      n_outputs=inputs_size,
      n_reservoir=reservoir_size,
      spectral_radius=spectral_radius,
      sparsity=sparsity
    )

    ## Constrói a rede neural
    nn_units_key = [value for value in max_units_architecture_binary if 'units' in value]
    nn_activation_key = [value for value in max_units_architecture_binary if 'activation' in value]


    def get_activation(activation):
        if activation == 0:
            return 'relu'
        elif activation == 1:
            return 'softmax'
     
    model = Sequential()
    first = True
    for key_units, key_activation in zip(nn_units_key, nn_activation_key):
        units = bin_array_to_dec(genetic_tape[map_genetic_tape[key_units]])
        activation = bin_array_to_dec(genetic_tape[map_genetic_tape[key_activation]])
        
        if first and units > 0:
            model.add(Dense(units=units, activation=get_activation(activation), input_shape=(inputs_size, ) ))
            first = False
        elif units > 0:
            model.add(Dense(units=units, activation=get_activation(activation) ))


    model.add(Dense(units=2, activation='softmax'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    #model.summary()

    return esn, model

# %%
def save_in_data_population(generation, individual, genetic_tape, time_exec, test_validation, esn_params, nn_params, df=None):
    global max_units_architecture_binary, map_genetic_tape
    ## Constrói a ESN.
    reservoir_size = bin_array_to_dec(genetic_tape[map_genetic_tape['-esn-reservoir_size']])
    outputs = 1
    spectral_radius = .8#(bin_array_to_dec(genetic_tape[map_genetic_tape['-esn-spectral_radius']]) / max_range_architecture_binary['-esn-spectral_radius'])
    sparsity = .8#(bin_array_to_dec(genetic_tape[map_genetic_tape['-esn-sparsity']]) / max_range_architecture_binary['-esn-sparsity'])
    
    row = {
        'generation': [generation],
        'individual': [individual],
        'reservoir_size': [reservoir_size],
        'outputs': [outputs],
        'spectral_radius': [spectral_radius],
        'sparsity': [sparsity],
    }
    
    def get_activation(activation):
        if activation == 0:
            return 'relu'
        elif activation == 1:
            return 'softmax'
            
    ## Constrói a rede neural
    nn_units_key = [value for value in max_units_architecture_binary if 'units' in value]
    nn_activation_key = [value for value in max_units_architecture_binary if 'activation' in value] 
    first = True
    hidden_layer = 0
    for key_units, key_activation in zip(nn_units_key, nn_activation_key):
        units = bin_array_to_dec(genetic_tape[map_genetic_tape[key_units]])
        activation = bin_array_to_dec(genetic_tape[map_genetic_tape[key_activation]])
        
        row[key_units] = [units]
        row[key_activation] = [get_activation(activation)]
        if units > 0:
            hidden_layer +=1
        
    row['time_exec'] = time_exec
    row['test_validation'] = test_validation
    row['esn_params'] = esn_params
    row['nn_params'] = nn_params
    row['nn_hidden_layer'] = hidden_layer


    ## Save score
    
    if type(df) == type(None):
        pd.DataFrame(row)
    
    return pd.concat([df, pd.DataFrame(row)]).reset_index(drop=True)

# %%
df_population = None

# %%
import time
def train(esn, nn):
    global train_X_normalized, train_Y_normalized, test_X_normalized, test_Y_normalized, y_train, y_test

    inicio_time = time.time()
    
    predict_esn_train = esn.fit(train_X_normalized, train_Y_normalized)
    #predict_esn_train = esn.get_reservoir_states(train_X_normalized.T)

    # Treinar o modelo
    nn.fit(predict_esn_train, y_train, batch_size=32, verbose=False, epochs=5)
    #predict_esn_test = esn.get_reservoir_states(test_X_normalized.T)
    predict_esn_test = esn.predict(test_X_normalized)
    predict_nn = nn.predict(predict_esn_test, verbose=False)

    y_pred_rounded = np.argmax(predict_nn, axis=1)
    y_test_rounded = np.argmax(y_test, axis=1)
     #validacao = np.asarray([all(value_predicted == value_y_test) for value_predicted, value_y_test in zip(predicted_onehotencoderT, y_test)])
    f1score = f1_score(y_pred_rounded, y_test_rounded)
    
    final_time = time.time() - inicio_time
    
    #return final_time, (validacao.sum() / validacao.shape[0])
    return final_time, f1score

# %%
def create_score(max_validation, max_esn_params, max_nn_params, validation, esn_params, nn_params, weight_validation, weight_esn_params, weight_nn_params ):
    global max_units

    if max_validation == 0:
        validation_perc = 0
    else:
        validation_perc = validation#(validation / max_validation) * weight_validation
    
    esn_params_perc = (1 - (esn_params / max_esn_params)) * weight_esn_params
    nn_params_perc = (1 - (nn_params / max_nn_params)) * weight_nn_params

    if nn_params <=  int(max_units * .0004):
        nn_params_perc = 0
    if esn_params <= int(max_reservoir_size * .0004):
        esn_params_perc = 0

    
    score = validation_perc + (esn_params_perc + nn_params_perc) 
    return score

# %%
def save_score_array(array_score, generation):
    global df_population
    
    print('save_score_array')
    print('{}'.format(df_population.loc[df_population['generation']==generation].shape))
    print('{}'.format(len(array_score)))
    df_population.loc[df_population['generation']==generation, 'score'] = array_score

    indices_maiores = np.argsort(array_score)[:pop_size-n_reinsertion]
    marcados = np.zeros_like(array_score)
    marcados[indices_maiores] = 1
    df_population.loc[df_population['generation']==generation, 'best'] = marcados

# %%
def fitness_function(generation):
    global df_population

    data_population = df_population.query(f'generation == {generation}')
    array_score = []

		
    max_validation = data_population['test_validation'].max()
    max_esn_params = data_population['esn_params'].max()
    max_nn_params = data_population['nn_params'].max()

    weight_validation = 1
    weight_esn_params = .1
    weight_nn_params = .1
    
    for index, individual in data_population.iterrows():
        array_score.append( create_score(max_validation, max_esn_params, max_nn_params, individual['test_validation'], individual['esn_params'], 
                           individual['nn_params'], weight_validation, weight_esn_params, weight_nn_params) )
        
    save_score_array(array_score, generation)
    return array_score

# %%
# def roulette(array_fitness, n_parents):
#     scores = array_fitness.copy()
#     #inverted_list = [max(scores) - score for score in scores]
#     # Encontre a soma das pontuações invertidas
#     total_score = sum(scores)
#     # Calcule as proporções da roleta
#     proportions = [s / total_score for s in scores]
#     #[print("{}: {:f}".format(enum, a)) for enum, a in enumerate(proportions)]
#     selected_index = np.random.choice(len(scores), size=n_parents, p=proportions)
#     return selected_index

# %%
def roulette(array_fitness, n_parents):
    scores = array_fitness.copy()
    total_score = sum(scores)
    
    # Verificar se todos os scores são iguais a zero
    if total_score == 0:
        proportions = [1 / len(scores)] * len(scores)  # Proporções iguais para todos os elementos
    else:
        proportions = [s / total_score for s in scores]
    
    selected_index = np.random.choice(len(scores), size=n_parents, p=proportions)
    return selected_index

# %%
def tournament(array_fitness, n_parents):
    return np.flip(np.argsort(array_fitness))[:n_parents]

# %%
def simple_crossover(population, array_parents, pop_size, num_genes, pop_random_perc):
    
    children = []
    pop_crossover = int(pop_size * (1-pop_random_perc))
    pop_random = int(pop_size - pop_crossover)
    pop_random+= pop_size - (pop_crossover + pop_random)

    print('\tA nova geração terá:')
    print(f'\t\t- {pop_crossover} população cruzada')
    print(f'\t\t- {pop_random} população aleatória')
    
    for individual in range(pop_crossover):
        ## Seleciona 2 pais para o cruzamento
        parentes = select_random_couples(array_parents)
        ## Define uma mascara de quais genes serão pegos entre o pai 1 e o pai 2
        #cross_mask = np.random.choice([0,1], size=num_genes)
        corte = np.random.randint(num_genes)
        cross_mask = np.asarray(( ([0]*corte) + ([1]*(num_genes-corte)) ))
        ## Construi o filho baseado na mascara acima.
        child = [population[parentes[father]][enum]  for enum, father in enumerate(cross_mask)]
        children.append(np.asarray(child))
      
    ## Gera filhos aleatórios para evitar convergência entre os individuos
    
    generate_random_individuals = init_population(pop_random)
    return np.concatenate( (children, generate_random_individuals) , axis=0)

# %%
def random_crossover(population, array_parents, pop_size, num_genes, pop_random_perc):
    
    children = []
    pop_crossover = int(pop_size * (1-pop_random_perc))
    pop_random = int(pop_size - pop_crossover)
    pop_random+= pop_size - (pop_crossover + pop_random)

    print('\tA nova geração terá:')
    print(f'\t\t- {pop_crossover} população cruzada')
    print(f'\t\t- {pop_random} população aleatória')
    
    for individual in range(pop_crossover):
        ## Seleciona 2 pais para o cruzamento
        parentes = select_random_couples(array_parents)
        ## Define uma mascara de quais genes serão pegos entre o pai 1 e o pai 2
        cross_mask = np.random.choice([0,1], size=num_genes)
        ## Construi o filho baseado na mascara acima.
        child = [population[parentes[father]][enum]  for enum, father in enumerate(cross_mask)]
        children.append(np.asarray(child))
      
    ## Gera filhos aleatórios para evitar convergência entre os individuos
    
    generate_random_individuals = init_population(pop_random)
    return np.concatenate( (children, generate_random_individuals) , axis=0)

# %%
def change_value(value):
    if value == 0:
        return 1
    else:
        return 0

# %%
def hamming_similarity(array1, array2):
    if len(array1) != len(array2):
        raise ValueError("Os arrays devem ter o mesmo comprimento.")
    
    num_different = sum(el1 != el2 for el1, el2 in zip(array1, array2))
    similarity = 1 - (num_different / len(array1))
    
    return similarity

# %%
def mutation(children_array, mutation_rate_normal=.05, mutation_rate_similarity=.2, similarity_mutation=.65):
    children_array = children_array.copy()
    ## Obtém os individuos com muita similaridade na população:
    # individuos_mutation = []
    
    # for enum1,ind1 in enumerate(children_array):
    #     similarity = []
    #     for enum2, ind2 in enumerate(children_array):
    #         if enum1 != enum2:
    #             similarity.append( hamming_similarity(ind1, ind2) )

    #     if np.asarray(similarity).mean() >= similarity_mutation:
    #         individuos_mutation.append(enum1)


    for index_children in range(len(children_array)):
        for index_gene in range(len(children_array[index_children])):
            value = np.random.randint(1, 101)
            # mutation = mutation_rate_normal
            # if index_children in individuos_mutation:
            #     mutation = mutation_rate_similarity
                
            if value/100 <= mutation_rate_normal:
                children_array[index_children][index_gene] = change_value(children_array[index_children][index_gene])
    
    return children_array

# %%
length_genetic_tape
# Out:
# 45

# %%
df_population = None

# %%
def reinsertion(population, children, pop_size, n_reinsertion, array_fitness):
    population_aux = population.copy()

    best_individuals_indexes = np.flip(np.argsort(array_fitness))[:pop_size-n_reinsertion]
    population_aux = np.concatenate(( np.asarray(population_aux[best_individuals_indexes]),  np.asarray(children) ), axis=0)
    return population_aux

# %%
df_population

# %%
def exec_train_for_population(generation, population):
    global df_population, n_reinsertion, pop_size, length_genetic_tape, pop_random_perc, n_parents_survive, first
    map_individual = {}
    
    for individual_enum, individual in enumerate(population):
        if individual_enum < pop_size-n_reinsertion and generation > 0:
            print('\t- [Campeão] Individuo {}'.format(individual_enum))
            df_last_generation = df_population.query('generation == {}'.format(generation-1))
            df_best_individual = df_last_generation.iloc[np.argsort(df_last_generation['score'])[::-1][individual_enum:individual_enum+1]]
            time_exec = df_best_individual['time_exec'].values[0]
            test_validation = df_best_individual['test_validation'].values[0]
            esn_params = df_best_individual['esn_params'].values[0]
            nn_params = df_best_individual['nn_params'].values[0]
            print('\t\t- Time: {} - Validation Test: {}'.format(round(time_exec, 2), round(test_validation, 2)))
            df_population = save_in_data_population(generation, individual_enum, individual, time_exec, test_validation, esn_params, nn_params, df_population)
        else:
            print('\t- [Novato] Individuo {}'.format(individual_enum))
            esn, nn = build_esn_nn_with_genetic_tape(individual)
            time_exec, test_validation = train(esn, nn)
            print('\t\t- Time: {} - Validation Test: {}'.format(round(time_exec, 2), round(test_validation, 2)))
            df_population = save_in_data_population(generation, individual_enum, individual, time_exec, test_validation, esn.count_parameters(), nn.count_params(), df_population)
    print('\t - Executa fitness_function')
    array_fitness = fitness_function(generation)
    print('\t - Executa tournament')
    selected_index = roulette(array_fitness, n_parents_survive)
    print('\t - random_crossover')
    children = simple_crossover(population.copy(), selected_index, n_reinsertion, length_genetic_tape, pop_random_perc)
    print('\t - childrens: {}'.format(children.shape))
    children = mutation(children)
    print('\t - mutation - childrens: {}'.format(children.shape))
    children = reinsertion(population, children, pop_size, n_reinsertion, array_fitness)
    print('\t - reinsertion - childrens: {}'.format(children.shape))
    print('\t - Métricas:')
    df_generation = df_population.query(f'generation == {generation}')

    validation_metrics = df_generation['test_validation'].mean()
    esn_params_metrics = df_generation['esn_params'].mean()
    nn_params_metrics = df_generation['nn_params'].mean()
    
    print(f'\t\t- validation_metrics: {validation_metrics}')
    print(f'\t\t- esn_params_metrics: {esn_params_metrics}')
    print(f'\t\t- nn_params_metrics: {nn_params_metrics}')
    
    return children

# %%
def select_random_couples(array_parents):
    return np.random.choice(array_parents, size=2, replace=False)

# %%
population = init_population(pop_size)
first = True
for epoch in range(generation):
    print('- Época {}'.format(epoch))
    children = exec_train_for_population(epoch, population)
    population = children.copy()
# Out:
# - Época 0
# 	- [Novato] Individuo 0
# 		- Time: 2.35 - Validation Test: 0.35
# 	- [Novato] Individuo 1
# 		- Time: 2.78 - Validation Test: 0.0
# 	- [Novato] Individuo 2
# 		- Time: 2.6 - Validation Test: 0.0
# 	- [Novato] Individuo 3
# 		- Time: 2.3 - Validation Test: 0.0
# 	- [Novato] Individuo 4
# 		- Time: 2.41 - Validation Test: 0.0
# 	- [Novato] Individuo 5
# 		- Time: 2.36 - Validation Test: 0.35
# 	- [Novato] Individuo 6
# 		- Time: 2.8 - Validation Test: 0.22
# 	- [Novato] Individuo 7
# 		- Time: 2.22 - Validation Test: 0.0
# 	- [Novato] Individuo 8
# 		- Time: 2.8 - Validation Test: 0.0
# 	- [Novato] Individuo 9
# 		- Time: 2.82 - Validation Test: 0.0
# 	- [Novato] Individuo 10
# 		- Time: 2.18 - Validation Test: 0.0
# 	- [Novato] Individuo 11
# 		- Time: 2.88 - Validation Test: 0.0
# 	- [Novato] Individuo 12
# 		- Time: 2.52 - Validation Test: 0.0
# 	- [Novato] Individuo 13
# 		- Time: 2.46 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 2.92 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 2.51 - Validation Test: 0.0
# 	- [Novato] Individuo 16
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Novato] Individuo 17
# 		- Time: 2.58 - Validation Test: 0.0
# 	- [Novato] Individuo 18
# 		- Time: 2.64 - Validation Test: 0.0
# 	- [Novato] Individuo 19
# 		- Time: 2.75 - Validation Test: 0.0
# 	- [Novato] Individuo 20
# 		- Time: 2.57 - Validation Test: 0.41
# 	- [Novato] Individuo 21
# 		- Time: 2.75 - Validation Test: 0.0
# 	- [Novato] Individuo 22
# 		- Time: 2.82 - Validation Test: 0.0
# 	- [Novato] Individuo 23
# 		- Time: 3.06 - Validation Test: 0.0
# 	- [Novato] Individuo 24
# 		- Time: 2.64 - Validation Test: 0.0
# 	- [Novato] Individuo 25
# 		- Time: 3.17 - Validation Test: 0.0
# 	- [Novato] Individuo 26
# 		- Time: 3.15 - Validation Test: 0.0
# 	- [Novato] Individuo 27
# 		- Time: 2.86 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 2.69 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 2.68 - Validation Test: 0.0
# 	- [Novato] Individuo 30
# 		- Time: 2.08 - Validation Test: 0.0
# 	- [Novato] Individuo 31
# 		- Time: 2.25 - Validation Test: 0.0
# 	- [Novato] Individuo 32
# 		- Time: 2.89 - Validation Test: 0.0
# 	- [Novato] Individuo 33
# 		- Time: 2.73 - Validation Test: 0.0
# 	- [Novato] Individuo 34
# 		- Time: 2.82 - Validation Test: 0.0
# 	- [Novato] Individuo 35
# 		- Time: 2.88 - Validation Test: 0.36
# 	- [Novato] Individuo 36
# 		- Time: 2.85 - Validation Test: 0.0
# 	- [Novato] Individuo 37
# 		- Time: 2.04 - Validation Test: 0.3
# 	- [Novato] Individuo 38
# 		- Time: 3.1 - Validation Test: 0.0
# 	- [Novato] Individuo 39
# 		- Time: 2.9 - Validation Test: 0.0
# 	- [Novato] Individuo 40
# 		- Time: 2.12 - Validation Test: 0.0
# 	- [Novato] Individuo 41
# 		- Time: 3.34 - Validation Test: 0.0
# 	- [Novato] Individuo 42
# 		- Time: 2.02 - Validation Test: 0.0
# 	- [Novato] Individuo 43
# 		- Time: 2.72 - Validation Test: 0.0
# 	- [Novato] Individuo 44
# 		- Time: 2.67 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 2.71 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 2.81 - Validation Test: 0.0
# 	- [Novato] Individuo 47
# 		- Time: 2.71 - Validation Test: 0.0
# 	- [Novato] Individuo 48
# 		- Time: 2.57 - Validation Test: 0.34
# 	- [Novato] Individuo 49
# 		- Time: 2.69 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 19)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.05654172401361651
# 		- esn_params_metrics: 5503983.56
# 		- nn_params_metrics: 594854.74
# - Época 1
# 	- [Campeão] Individuo 0
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 1
# 		- Time: 2.57 - Validation Test: 0.41
# 	- [Campeão] Individuo 2
# 		- Time: 2.35 - Validation Test: 0.35
# 	- [Campeão] Individuo 3
# 		- Time: 2.36 - Validation Test: 0.35
# 	- [Campeão] Individuo 4
# 		- Time: 2.88 - Validation Test: 0.36
# 	- [Campeão] Individuo 5
# 		- Time: 2.04 - Validation Test: 0.3
# 	- [Campeão] Individuo 6
# 		- Time: 2.57 - Validation Test: 0.34
# 	- [Campeão] Individuo 7
# 		- Time: 2.8 - Validation Test: 0.22
# 	- [Campeão] Individuo 8
# 		- Time: 2.02 - Validation Test: 0.0
# 	- [Campeão] Individuo 9
# 		- Time: 2.08 - Validation Test: 0.0
# 	- [Novato] Individuo 10
# 		- Time: 2.92 - Validation Test: 0.0
# 	- [Novato] Individuo 11
# 		- Time: 2.28 - Validation Test: 0.0
# 	- [Novato] Individuo 12
# 		- Time: 2.95 - Validation Test: 0.05
# 	- [Novato] Individuo 13
# 		- Time: 2.51 - Validation Test: 0.21
# 	- [Novato] Individuo 14
# 		- Time: 2.71 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 2.21 - Validation Test: 0.29
# 	- [Novato] Individuo 16
# 		- Time: 2.94 - Validation Test: 0.0
# 	- [Novato] Individuo 17
# 		- Time: 2.41 - Validation Test: 0.0
# 	- [Novato] Individuo 18
# 		- Time: 3.27 - Validation Test: 0.0
# 	- [Novato] Individuo 19
# 		- Time: 2.37 - Validation Test: 0.21
# 	- [Novato] Individuo 20
# 		- Time: 2.2 - Validation Test: 0.0
# 	- [Novato] Individuo 21
# 		- Time: 2.36 - Validation Test: 0.22
# 	- [Novato] Individuo 22
# 		- Time: 3.33 - Validation Test: 0.16
# 	- [Novato] Individuo 23
# 		- Time: 2.92 - Validation Test: 0.0
# 	- [Novato] Individuo 24
# 		- Time: 2.94 - Validation Test: 0.18
# 	- [Novato] Individuo 25
# 		- Time: 2.63 - Validation Test: 0.09
# 	- [Novato] Individuo 26
# 		- Time: 2.25 - Validation Test: 0.0
# 	- [Novato] Individuo 27
# 		- Time: 2.98 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 2.72 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 2.23 - Validation Test: 0.23
# 	- [Novato] Individuo 30
# 		- Time: 1.97 - Validation Test: 0.29
# 	- [Novato] Individuo 31
# 		- Time: 3.06 - Validation Test: 0.27
# 	- [Novato] Individuo 32
# 		- Time: 2.99 - Validation Test: 0.0
# 	- [Novato] Individuo 33
# 		- Time: 2.34 - Validation Test: 0.0
# 	- [Novato] Individuo 34
# 		- Time: 2.85 - Validation Test: 0.0
# 	- [Novato] Individuo 35
# 		- Time: 2.33 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 2.93 - Validation Test: 0.0
# 	- [Novato] Individuo 37
# 		- Time: 3.27 - Validation Test: 0.0
# 	- [Novato] Individuo 38
# 		- Time: 3.0 - Validation Test: 0.06
# 	- [Novato] Individuo 39
# 		- Time: 2.9 - Validation Test: 0.38
# 	- [Novato] Individuo 40
# 		- Time: 3.01 - Validation Test: 0.06
# 	- [Novato] Individuo 41
# 		- Time: 2.3 - Validation Test: 0.0
# 	- [Novato] Individuo 42
# 		- Time: 2.0 - Validation Test: 0.0
# 	- [Novato] Individuo 43
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Novato] Individuo 44
# 		- Time: 2.06 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 2.29 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 2.74 - Validation Test: 0.0
# 	- [Novato] Individuo 47
# 		- Time: 2.71 - Validation Test: 0.16
# 	- [Novato] Individuo 48
# 		- Time: 2.39 - Validation Test: 0.41
# 	- [Novato] Individuo 49
# 		- Time: 2.73 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.13132415630725436
# 		- esn_params_metrics: 5223689.38
# 		- nn_params_metrics: 529063.52
# - Época 2
# 	- [Campeão] Individuo 0
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 1
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Campeão] Individuo 2
# 		- Time: 2.39 - Validation Test: 0.41
# 	- [Campeão] Individuo 3
# 		- Time: 2.57 - Validation Test: 0.41
# 	- [Campeão] Individuo 4
# 		- Time: 2.35 - Validation Test: 0.35
# 	- [Campeão] Individuo 5
# 		- Time: 2.36 - Validation Test: 0.35
# 	- [Campeão] Individuo 6
# 		- Time: 2.88 - Validation Test: 0.36
# 	- [Campeão] Individuo 7
# 		- Time: 1.97 - Validation Test: 0.29
# 	- [Campeão] Individuo 8
# 		- Time: 2.04 - Validation Test: 0.3
# 	- [Campeão] Individuo 9
# 		- Time: 2.9 - Validation Test: 0.38
# 	- [Novato] Individuo 10
# 		- Time: 2.47 - Validation Test: 0.26
# 	- [Novato] Individuo 11
# 		- Time: 2.94 - Validation Test: 0.0
# 	- [Novato] Individuo 12
# 		- Time: 2.19 - Validation Test: 0.0
# 	- [Novato] Individuo 13
# 		- Time: 2.74 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 2.5 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 2.27 - Validation Test: 0.0
# 	- [Novato] Individuo 16
# 		- Time: 1.96 - Validation Test: 0.31
# 	- [Novato] Individuo 17
# 		- Time: 2.36 - Validation Test: 0.0
# 	- [Novato] Individuo 18
# 		- Time: 2.75 - Validation Test: 0.0
# 	- [Novato] Individuo 19
# 		- Time: 2.5 - Validation Test: 0.0
# 	- [Novato] Individuo 20
# 		- Time: 2.02 - Validation Test: 0.33
# 	- [Novato] Individuo 21
# 		- Time: 2.56 - Validation Test: 0.24
# 	- [Novato] Individuo 22
# 		- Time: 2.2 - Validation Test: 0.0
# 	- [Novato] Individuo 23
# 		- Time: 2.53 - Validation Test: 0.0
# 	- [Novato] Individuo 24
# 		- Time: 2.45 - Validation Test: 0.0
# 	- [Novato] Individuo 25
# 		- Time: 2.55 - Validation Test: 0.0
# 	- [Novato] Individuo 26
# 		- Time: 2.75 - Validation Test: 0.0
# 	- [Novato] Individuo 27
# 		- Time: 2.62 - Validation Test: 0.25
# 	- [Novato] Individuo 28
# 		- Time: 2.42 - Validation Test: 0.24
# 	- [Novato] Individuo 29
# 		- Time: 1.9 - Validation Test: 0.14
# 	- [Novato] Individuo 30
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Novato] Individuo 31
# 		- Time: 2.34 - Validation Test: 0.21
# 	- [Novato] Individuo 32
# 		- Time: 2.44 - Validation Test: 0.18
# 	- [Novato] Individuo 33
# 		- Time: 2.36 - Validation Test: 0.39
# 	- [Novato] Individuo 34
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Novato] Individuo 35
# 		- Time: 2.52 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 2.56 - Validation Test: 0.15
# 	- [Novato] Individuo 37
# 		- Time: 1.91 - Validation Test: 0.0
# 	- [Novato] Individuo 38
# 		- Time: 1.98 - Validation Test: 0.0
# 	- [Novato] Individuo 39
# 		- Time: 2.19 - Validation Test: 0.0
# 	- [Novato] Individuo 40
# 		- Time: 2.63 - Validation Test: 0.0
# 	- [Novato] Individuo 41
# 		- Time: 2.41 - Validation Test: 0.21
# 	- [Novato] Individuo 42
# 		- Time: 2.46 - Validation Test: 0.15
# 	- [Novato] Individuo 43
# 		- Time: 2.65 - Validation Test: 0.3
# 	- [Novato] Individuo 44
# 		- Time: 2.31 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 2.36 - Validation Test: 0.34
# 	- [Novato] Individuo 46
# 		- Time: 2.41 - Validation Test: 0.2
# 	- [Novato] Individuo 47
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Novato] Individuo 48
# 		- Time: 2.66 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.56 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.18006598938546617
# 		- esn_params_metrics: 5336854.56
# 		- nn_params_metrics: 443271.84
# - Época 3
# 	- [Campeão] Individuo 0
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 1
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 2
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 3
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Campeão] Individuo 4
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Campeão] Individuo 5
# 		- Time: 2.39 - Validation Test: 0.41
# 	- [Campeão] Individuo 6
# 		- Time: 2.57 - Validation Test: 0.41
# 	- [Campeão] Individuo 7
# 		- Time: 2.36 - Validation Test: 0.39
# 	- [Campeão] Individuo 8
# 		- Time: 2.36 - Validation Test: 0.34
# 	- [Campeão] Individuo 9
# 		- Time: 2.02 - Validation Test: 0.33
# 	- [Novato] Individuo 10
# 		- Time: 1.85 - Validation Test: 0.27
# 	- [Novato] Individuo 11
# 		- Time: 1.87 - Validation Test: 0.15
# 	- [Novato] Individuo 12
# 		- Time: 2.37 - Validation Test: 0.0
# 	- [Novato] Individuo 13
# 		- Time: 1.88 - Validation Test: 0.26
# 	- [Novato] Individuo 14
# 		- Time: 2.59 - Validation Test: 0.17
# 	- [Novato] Individuo 15
# 		- Time: 2.36 - Validation Test: 0.33
# 	- [Novato] Individuo 16
# 		- Time: 1.93 - Validation Test: 0.34
# 	- [Novato] Individuo 17
# 		- Time: 2.73 - Validation Test: 0.0
# 	- [Novato] Individuo 18
# 		- Time: 2.39 - Validation Test: 0.12
# 	- [Novato] Individuo 19
# 		- Time: 2.24 - Validation Test: 0.3
# 	- [Novato] Individuo 20
# 		- Time: 2.11 - Validation Test: 0.42
# 	- [Novato] Individuo 21
# 		- Time: 1.86 - Validation Test: 0.36
# 	- [Novato] Individuo 22
# 		- Time: 1.87 - Validation Test: 0.33
# 	- [Novato] Individuo 23
# 		- Time: 2.31 - Validation Test: 0.4
# 	- [Novato] Individuo 24
# 		- Time: 2.15 - Validation Test: 0.29
# 	- [Novato] Individuo 25
# 		- Time: 1.95 - Validation Test: 0.33
# 	- [Novato] Individuo 26
# 		- Time: 1.9 - Validation Test: 0.37
# 	- [Novato] Individuo 27
# 		- Time: 2.15 - Validation Test: 0.06
# 	- [Novato] Individuo 28
# 		- Time: 1.93 - Validation Test: 0.35
# 	- [Novato] Individuo 29
# 		- Time: 1.82 - Validation Test: 0.0
# 	- [Novato] Individuo 30
# 		- Time: 2.28 - Validation Test: 0.25
# 	- [Novato] Individuo 31
# 		- Time: 2.48 - Validation Test: 0.32
# 	- [Novato] Individuo 32
# 		- Time: 2.54 - Validation Test: 0.34
# 	- [Novato] Individuo 33
# 		- Time: 2.81 - Validation Test: 0.3
# 	- [Novato] Individuo 34
# 		- Time: 2.43 - Validation Test: 0.15
# 	- [Novato] Individuo 35
# 		- Time: 1.91 - Validation Test: 0.31
# 	- [Novato] Individuo 36
# 		- Time: 2.07 - Validation Test: 0.34
# 	- [Novato] Individuo 37
# 		- Time: 2.33 - Validation Test: 0.06
# 	- [Novato] Individuo 38
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Novato] Individuo 39
# 		- Time: 2.48 - Validation Test: 0.24
# 	- [Novato] Individuo 40
# 		- Time: 2.42 - Validation Test: 0.4
# 	- [Novato] Individuo 41
# 		- Time: 2.71 - Validation Test: 0.33
# 	- [Novato] Individuo 42
# 		- Time: 2.4 - Validation Test: 0.35
# 	- [Novato] Individuo 43
# 		- Time: 1.92 - Validation Test: 0.25
# 	- [Novato] Individuo 44
# 		- Time: 2.43 - Validation Test: 0.23
# 	- [Novato] Individuo 45
# 		- Time: 1.87 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 1.92 - Validation Test: 0.17
# 	- [Novato] Individuo 47
# 		- Time: 2.38 - Validation Test: 0.33
# 	- [Novato] Individuo 48
# 		- Time: 2.26 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.75 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.2771716863572504
# 		- esn_params_metrics: 4817785.46
# 		- nn_params_metrics: 348471.02
# - Época 4
# 	- [Campeão] Individuo 0
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 1
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 2
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 3
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 4
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Campeão] Individuo 5
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Campeão] Individuo 6
# 		- Time: 2.31 - Validation Test: 0.4
# 	- [Campeão] Individuo 7
# 		- Time: 2.11 - Validation Test: 0.42
# 	- [Campeão] Individuo 8
# 		- Time: 1.9 - Validation Test: 0.37
# 	- [Campeão] Individuo 9
# 		- Time: 1.86 - Validation Test: 0.36
# 	- [Novato] Individuo 10
# 		- Time: 2.22 - Validation Test: 0.17
# 	- [Novato] Individuo 11
# 		- Time: 2.44 - Validation Test: 0.34
# 	- [Novato] Individuo 12
# 		- Time: 1.95 - Validation Test: 0.06
# 	- [Novato] Individuo 13
# 		- Time: 1.88 - Validation Test: 0.34
# 	- [Novato] Individuo 14
# 		- Time: 1.89 - Validation Test: 0.21
# 	- [Novato] Individuo 15
# 		- Time: 2.44 - Validation Test: 0.47
# 	- [Novato] Individuo 16
# 		- Time: 2.18 - Validation Test: 0.0
# 	- [Novato] Individuo 17
# 		- Time: 1.87 - Validation Test: 0.28
# 	- [Novato] Individuo 18
# 		- Time: 1.99 - Validation Test: 0.33
# 	- [Novato] Individuo 19
# 		- Time: 2.18 - Validation Test: 0.0
# 	- [Novato] Individuo 20
# 		- Time: 2.38 - Validation Test: 0.32
# 	- [Novato] Individuo 21
# 		- Time: 1.99 - Validation Test: 0.17
# 	- [Novato] Individuo 22
# 		- Time: 1.96 - Validation Test: 0.23
# 	- [Novato] Individuo 23
# 		- Time: 2.48 - Validation Test: 0.06
# 	- [Novato] Individuo 24
# 		- Time: 2.02 - Validation Test: 0.11
# 	- [Novato] Individuo 25
# 		- Time: 1.92 - Validation Test: 0.17
# 	- [Novato] Individuo 26
# 		- Time: 1.94 - Validation Test: 0.22
# 	- [Novato] Individuo 27
# 		- Time: 2.57 - Validation Test: 0.26
# 	- [Novato] Individuo 28
# 		- Time: 2.35 - Validation Test: 0.29
# 	- [Novato] Individuo 29
# 		- Time: 2.15 - Validation Test: 0.26
# 	- [Novato] Individuo 30
# 		- Time: 2.05 - Validation Test: 0.27
# 	- [Novato] Individuo 31
# 		- Time: 2.41 - Validation Test: 0.28
# 	- [Novato] Individuo 32
# 		- Time: 2.42 - Validation Test: 0.0
# 	- [Novato] Individuo 33
# 		- Time: 2.01 - Validation Test: 0.31
# 	- [Novato] Individuo 34
# 		- Time: 2.01 - Validation Test: 0.36
# 	- [Novato] Individuo 35
# 		- Time: 2.0 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 1.86 - Validation Test: 0.27
# 	- [Novato] Individuo 37
# 		- Time: 1.78 - Validation Test: 0.31
# 	- [Novato] Individuo 38
# 		- Time: 2.79 - Validation Test: 0.11
# 	- [Novato] Individuo 39
# 		- Time: 2.07 - Validation Test: 0.34
# 	- [Novato] Individuo 40
# 		- Time: 2.51 - Validation Test: 0.37
# 	- [Novato] Individuo 41
# 		- Time: 1.96 - Validation Test: 0.29
# 	- [Novato] Individuo 42
# 		- Time: 1.9 - Validation Test: 0.35
# 	- [Novato] Individuo 43
# 		- Time: 2.46 - Validation Test: 0.15
# 	- [Novato] Individuo 44
# 		- Time: 1.96 - Validation Test: 0.31
# 	- [Novato] Individuo 45
# 		- Time: 1.86 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 1.91 - Validation Test: 0.15
# 	- [Novato] Individuo 47
# 		- Time: 2.13 - Validation Test: 0.33
# 	- [Novato] Individuo 48
# 		- Time: 2.39 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 3.14 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.25518172380708604
# 		- esn_params_metrics: 4840688.52
# 		- nn_params_metrics: 275407.64
# - Época 5
# 	- [Campeão] Individuo 0
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 1
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 2
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 3
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 4
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Campeão] Individuo 5
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Campeão] Individuo 6
# 		- Time: 2.31 - Validation Test: 0.4
# 	- [Campeão] Individuo 7
# 		- Time: 2.44 - Validation Test: 0.47
# 	- [Campeão] Individuo 8
# 		- Time: 2.11 - Validation Test: 0.42
# 	- [Campeão] Individuo 9
# 		- Time: 1.9 - Validation Test: 0.37
# 	- [Novato] Individuo 10
# 		- Time: 1.92 - Validation Test: 0.29
# 	- [Novato] Individuo 11
# 		- Time: 1.91 - Validation Test: 0.27
# 	- [Novato] Individuo 12
# 		- Time: 1.92 - Validation Test: 0.37
# 	- [Novato] Individuo 13
# 		- Time: 1.9 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 1.89 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 1.9 - Validation Test: 0.42
# 	- [Novato] Individuo 16
# 		- Time: 1.93 - Validation Test: 0.31
# 	- [Novato] Individuo 17
# 		- Time: 2.18 - Validation Test: 0.35
# 	- [Novato] Individuo 18
# 		- Time: 1.95 - Validation Test: 0.26
# 	- [Novato] Individuo 19
# 		- Time: 2.63 - Validation Test: 0.34
# 	- [Novato] Individuo 20
# 		- Time: 1.99 - Validation Test: 0.0
# 	- [Novato] Individuo 21
# 		- Time: 2.66 - Validation Test: 0.27
# 	- [Novato] Individuo 22
# 		- Time: 2.11 - Validation Test: 0.0
# 	- [Novato] Individuo 23
# 		- Time: 2.41 - Validation Test: 0.2
# 	- [Novato] Individuo 24
# 		- Time: 1.89 - Validation Test: 0.0
# 	- [Novato] Individuo 25
# 		- Time: 2.39 - Validation Test: 0.41
# 	- [Novato] Individuo 26
# 		- Time: 2.16 - Validation Test: 0.25
# 	- [Novato] Individuo 27
# 		- Time: 2.73 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 1.89 - Validation Test: 0.17
# 	- [Novato] Individuo 29
# 		- Time: 1.9 - Validation Test: 0.29
# 	- [Novato] Individuo 30
# 		- Time: 2.01 - Validation Test: 0.33
# 	- [Novato] Individuo 31
# 		- Time: 1.93 - Validation Test: 0.0
# 	- [Novato] Individuo 32
# 		- Time: 2.01 - Validation Test: 0.2
# 	- [Novato] Individuo 33
# 		- Time: 2.48 - Validation Test: 0.37
# 	- [Novato] Individuo 34
# 		- Time: 2.4 - Validation Test: 0.0
# 	- [Novato] Individuo 35
# 		- Time: 1.91 - Validation Test: 0.41
# 	- [Novato] Individuo 36
# 		- Time: 2.39 - Validation Test: 0.26
# 	- [Novato] Individuo 37
# 		- Time: 1.98 - Validation Test: 0.26
# 	- [Novato] Individuo 38
# 		- Time: 2.19 - Validation Test: 0.0
# 	- [Novato] Individuo 39
# 		- Time: 2.4 - Validation Test: 0.29
# 	- [Novato] Individuo 40
# 		- Time: 1.95 - Validation Test: 0.24
# 	- [Novato] Individuo 41
# 		- Time: 2.04 - Validation Test: 0.27
# 	- [Novato] Individuo 42
# 		- Time: 1.89 - Validation Test: 0.33
# 	- [Novato] Individuo 43
# 		- Time: 2.04 - Validation Test: 0.11
# 	- [Novato] Individuo 44
# 		- Time: 1.91 - Validation Test: 0.13
# 	- [Novato] Individuo 45
# 		- Time: 2.28 - Validation Test: 0.33
# 	- [Novato] Individuo 46
# 		- Time: 2.35 - Validation Test: 0.24
# 	- [Novato] Individuo 47
# 		- Time: 1.91 - Validation Test: 0.21
# 	- [Novato] Individuo 48
# 		- Time: 2.59 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.73 - Validation Test: 0.12
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.25384050132503144
# 		- esn_params_metrics: 4741376.72
# 		- nn_params_metrics: 273681.62
# - Época 6
# 	- [Campeão] Individuo 0
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 1
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 2
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 3
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 4
# 		- Time: 1.9 - Validation Test: 0.42
# 	- [Campeão] Individuo 5
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Campeão] Individuo 6
# 		- Time: 1.91 - Validation Test: 0.41
# 	- [Campeão] Individuo 7
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Campeão] Individuo 8
# 		- Time: 2.31 - Validation Test: 0.4
# 	- [Campeão] Individuo 9
# 		- Time: 2.11 - Validation Test: 0.42
# 	- [Novato] Individuo 10
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Novato] Individuo 11
# 		- Time: 2.0 - Validation Test: 0.29
# 	- [Novato] Individuo 12
# 		- Time: 1.85 - Validation Test: 0.28
# 	- [Novato] Individuo 13
# 		- Time: 2.3 - Validation Test: 0.36
# 	- [Novato] Individuo 14
# 		- Time: 2.02 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Novato] Individuo 16
# 		- Time: 1.91 - Validation Test: 0.09
# 	- [Novato] Individuo 17
# 		- Time: 2.29 - Validation Test: 0.15
# 	- [Novato] Individuo 18
# 		- Time: 2.69 - Validation Test: 0.16
# 	- [Novato] Individuo 19
# 		- Time: 1.89 - Validation Test: 0.23
# 	- [Novato] Individuo 20
# 		- Time: 2.2 - Validation Test: 0.4
# 	- [Novato] Individuo 21
# 		- Time: 1.88 - Validation Test: 0.0
# 	- [Novato] Individuo 22
# 		- Time: 1.86 - Validation Test: 0.21
# 	- [Novato] Individuo 23
# 		- Time: 2.72 - Validation Test: 0.16
# 	- [Novato] Individuo 24
# 		- Time: 2.36 - Validation Test: 0.35
# 	- [Novato] Individuo 25
# 		- Time: 2.46 - Validation Test: 0.0
# 	- [Novato] Individuo 26
# 		- Time: 2.71 - Validation Test: 0.06
# 	- [Novato] Individuo 27
# 		- Time: 2.46 - Validation Test: 0.2
# 	- [Novato] Individuo 28
# 		- Time: 1.77 - Validation Test: 0.1
# 	- [Novato] Individuo 29
# 		- Time: 2.05 - Validation Test: 0.0
# 	- [Novato] Individuo 30
# 		- Time: 1.87 - Validation Test: 0.37
# 	- [Novato] Individuo 31
# 		- Time: 2.45 - Validation Test: 0.24
# 	- [Novato] Individuo 32
# 		- Time: 2.31 - Validation Test: 0.3
# 	- [Novato] Individuo 33
# 		- Time: 1.88 - Validation Test: 0.35
# 	- [Novato] Individuo 34
# 		- Time: 2.82 - Validation Test: 0.28
# 	- [Novato] Individuo 35
# 		- Time: 2.01 - Validation Test: 0.21
# 	- [Novato] Individuo 36
# 		- Time: 1.91 - Validation Test: 0.36
# 	- [Novato] Individuo 37
# 		- Time: 2.73 - Validation Test: 0.0
# 	- [Novato] Individuo 38
# 		- Time: 1.91 - Validation Test: 0.21
# 	- [Novato] Individuo 39
# 		- Time: 2.41 - Validation Test: 0.26
# 	- [Novato] Individuo 40
# 		- Time: 1.91 - Validation Test: 0.29
# 	- [Novato] Individuo 41
# 		- Time: 1.78 - Validation Test: 0.2
# 	- [Novato] Individuo 42
# 		- Time: 2.57 - Validation Test: 0.16
# 	- [Novato] Individuo 43
# 		- Time: 2.91 - Validation Test: 0.39
# 	- [Novato] Individuo 44
# 		- Time: 2.25 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 2.1 - Validation Test: 0.4
# 	- [Novato] Individuo 46
# 		- Time: 1.97 - Validation Test: 0.28
# 	- [Novato] Individuo 47
# 		- Time: 2.74 - Validation Test: 0.1
# 	- [Novato] Individuo 48
# 		- Time: 2.91 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.37 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.2574163207110019
# 		- esn_params_metrics: 4805735.16
# 		- nn_params_metrics: 354200.76
# - Época 7
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 2
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 3
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 4
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 5
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 6
# 		- Time: 1.9 - Validation Test: 0.42
# 	- [Campeão] Individuo 7
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Campeão] Individuo 8
# 		- Time: 2.65 - Validation Test: 0.47
# 	- [Campeão] Individuo 9
# 		- Time: 1.91 - Validation Test: 0.41
# 	- [Novato] Individuo 10
# 		- Time: 2.15 - Validation Test: 0.23
# 	- [Novato] Individuo 11
# 		- Time: 2.02 - Validation Test: 0.24
# 	- [Novato] Individuo 12
# 		- Time: 2.29 - Validation Test: 0.0
# 	- [Novato] Individuo 13
# 		- Time: 3.13 - Validation Test: 0.12
# 	- [Novato] Individuo 14
# 		- Time: 2.08 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 2.0 - Validation Test: 0.24
# 	- [Novato] Individuo 16
# 		- Time: 2.19 - Validation Test: 0.38
# 	- [Novato] Individuo 17
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Novato] Individuo 18
# 		- Time: 2.2 - Validation Test: 0.0
# 	- [Novato] Individuo 19
# 		- Time: 2.16 - Validation Test: 0.33
# 	- [Novato] Individuo 20
# 		- Time: 1.9 - Validation Test: 0.37
# 	- [Novato] Individuo 21
# 		- Time: 2.14 - Validation Test: 0.26
# 	- [Novato] Individuo 22
# 		- Time: 1.93 - Validation Test: 0.43
# 	- [Novato] Individuo 23
# 		- Time: 2.61 - Validation Test: 0.0
# 	- [Novato] Individuo 24
# 		- Time: 2.05 - Validation Test: 0.0
# 	- [Novato] Individuo 25
# 		- Time: 2.24 - Validation Test: 0.26
# 	- [Novato] Individuo 26
# 		- Time: 2.33 - Validation Test: 0.31
# 	- [Novato] Individuo 27
# 		- Time: 2.09 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 1.97 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 1.97 - Validation Test: 0.0
# 	- [Novato] Individuo 30
# 		- Time: 2.31 - Validation Test: 0.29
# 	- [Novato] Individuo 31
# 		- Time: 2.35 - Validation Test: 0.33
# 	- [Novato] Individuo 32
# 		- Time: 2.51 - Validation Test: 0.11
# 	- [Novato] Individuo 33
# 		- Time: 1.99 - Validation Test: 0.0
# 	- [Novato] Individuo 34
# 		- Time: 2.57 - Validation Test: 0.31
# 	- [Novato] Individuo 35
# 		- Time: 2.4 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 1.87 - Validation Test: 0.26
# 	- [Novato] Individuo 37
# 		- Time: 1.94 - Validation Test: 0.0
# 	- [Novato] Individuo 38
# 		- Time: 2.2 - Validation Test: 0.0
# 	- [Novato] Individuo 39
# 		- Time: 2.17 - Validation Test: 0.12
# 	- [Novato] Individuo 40
# 		- Time: 2.29 - Validation Test: 0.12
# 	- [Novato] Individuo 41
# 		- Time: 2.74 - Validation Test: 0.05
# 	- [Novato] Individuo 42
# 		- Time: 2.52 - Validation Test: 0.42
# 	- [Novato] Individuo 43
# 		- Time: 1.9 - Validation Test: 0.23
# 	- [Novato] Individuo 44
# 		- Time: 1.92 - Validation Test: 0.2
# 	- [Novato] Individuo 45
# 		- Time: 2.44 - Validation Test: 0.23
# 	- [Novato] Individuo 46
# 		- Time: 1.96 - Validation Test: 0.17
# 	- [Novato] Individuo 47
# 		- Time: 2.07 - Validation Test: 0.0
# 	- [Novato] Individuo 48
# 		- Time: 2.91 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.52 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.22290155895741967
# 		- esn_params_metrics: 5225162.72
# 		- nn_params_metrics: 236131.56
# - Época 8
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 2
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Campeão] Individuo 3
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 4
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 5
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 6
# 		- Time: 1.93 - Validation Test: 0.43
# 	- [Campeão] Individuo 7
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 8
# 		- Time: 1.9 - Validation Test: 0.42
# 	- [Campeão] Individuo 9
# 		- Time: 1.87 - Validation Test: 0.42
# 	- [Novato] Individuo 10
# 		- Time: 2.05 - Validation Test: 0.0
# 	- [Novato] Individuo 11
# 		- Time: 2.17 - Validation Test: 0.43
# 	- [Novato] Individuo 12
# 		- Time: 1.99 - Validation Test: 0.0
# 	- [Novato] Individuo 13
# 		- Time: 1.93 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 2.03 - Validation Test: 0.0
# 	- [Novato] Individuo 15
# 		- Time: 1.96 - Validation Test: 0.29
# 	- [Novato] Individuo 16
# 		- Time: 2.02 - Validation Test: 0.31
# 	- [Novato] Individuo 17
# 		- Time: 2.45 - Validation Test: 0.36
# 	- [Novato] Individuo 18
# 		- Time: 2.3 - Validation Test: 0.19
# 	- [Novato] Individuo 19
# 		- Time: 1.95 - Validation Test: 0.38
# 	- [Novato] Individuo 20
# 		- Time: 1.94 - Validation Test: 0.28
# 	- [Novato] Individuo 21
# 		- Time: 2.38 - Validation Test: 0.0
# 	- [Novato] Individuo 22
# 		- Time: 1.93 - Validation Test: 0.35
# 	- [Novato] Individuo 23
# 		- Time: 2.47 - Validation Test: 0.28
# 	- [Novato] Individuo 24
# 		- Time: 2.53 - Validation Test: 0.33
# 	- [Novato] Individuo 25
# 		- Time: 1.89 - Validation Test: 0.15
# 	- [Novato] Individuo 26
# 		- Time: 1.99 - Validation Test: 0.17
# 	- [Novato] Individuo 27
# 		- Time: 1.93 - Validation Test: 0.33
# 	- [Novato] Individuo 28
# 		- Time: 1.98 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 2.0 - Validation Test: 0.06
# 	- [Novato] Individuo 30
# 		- Time: 2.35 - Validation Test: 0.22
# 	- [Novato] Individuo 31
# 		- Time: 1.89 - Validation Test: 0.42
# 	- [Novato] Individuo 32
# 		- Time: 1.99 - Validation Test: 0.31
# 	- [Novato] Individuo 33
# 		- Time: 2.25 - Validation Test: 0.29
# 	- [Novato] Individuo 34
# 		- Time: 2.0 - Validation Test: 0.21
# 	- [Novato] Individuo 35
# 		- Time: 2.48 - Validation Test: 0.16
# 	- [Novato] Individuo 36
# 		- Time: 2.15 - Validation Test: 0.36
# 	- [Novato] Individuo 37
# 		- Time: 1.88 - Validation Test: 0.11
# 	- [Novato] Individuo 38
# 		- Time: 1.95 - Validation Test: 0.19
# 	- [Novato] Individuo 39
# 		- Time: 2.24 - Validation Test: 0.3
# 	- [Novato] Individuo 40
# 		- Time: 2.39 - Validation Test: 0.0
# 	- [Novato] Individuo 41
# 		- Time: 1.94 - Validation Test: 0.29
# 	- [Novato] Individuo 42
# 		- Time: 1.97 - Validation Test: 0.0
# 	- [Novato] Individuo 43
# 		- Time: 2.01 - Validation Test: 0.0
# 	- [Novato] Individuo 44
# 		- Time: 2.17 - Validation Test: 0.37
# 	- [Novato] Individuo 45
# 		- Time: 2.56 - Validation Test: 0.3
# 	- [Novato] Individuo 46
# 		- Time: 2.33 - Validation Test: 0.26
# 	- [Novato] Individuo 47
# 		- Time: 1.92 - Validation Test: 0.15
# 	- [Novato] Individuo 48
# 		- Time: 2.56 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.56 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.25045333451634605
# 		- esn_params_metrics: 4991395.28
# 		- nn_params_metrics: 187409.1
# - Época 9
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Campeão] Individuo 2
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 3
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 4
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 5
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 6
# 		- Time: 2.17 - Validation Test: 0.43
# 	- [Campeão] Individuo 7
# 		- Time: 1.93 - Validation Test: 0.43
# 	- [Campeão] Individuo 8
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 9
# 		- Time: 1.9 - Validation Test: 0.42
# 	- [Novato] Individuo 10
# 		- Time: 2.01 - Validation Test: 0.0
# 	- [Novato] Individuo 11
# 		- Time: 1.92 - Validation Test: 0.0
# 	- [Novato] Individuo 12
# 		- Time: 1.92 - Validation Test: 0.2
# 	- [Novato] Individuo 13
# 		- Time: 1.98 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 1.91 - Validation Test: 0.27
# 	- [Novato] Individuo 15
# 		- Time: 2.2 - Validation Test: 0.33
# 	- [Novato] Individuo 16
# 		- Time: 2.01 - Validation Test: 0.16
# 	- [Novato] Individuo 17
# 		- Time: 2.12 - Validation Test: 0.0
# 	- [Novato] Individuo 18
# 		- Time: 2.12 - Validation Test: 0.17
# 	- [Novato] Individuo 19
# 		- Time: 2.35 - Validation Test: 0.1
# 	- [Novato] Individuo 20
# 		- Time: 1.94 - Validation Test: 0.24
# 	- [Novato] Individuo 21
# 		- Time: 1.89 - Validation Test: 0.24
# 	- [Novato] Individuo 22
# 		- Time: 1.91 - Validation Test: 0.3
# 	- [Novato] Individuo 23
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Novato] Individuo 24
# 		- Time: 2.01 - Validation Test: 0.19
# 	- [Novato] Individuo 25
# 		- Time: 2.13 - Validation Test: 0.0
# 	- [Novato] Individuo 26
# 		- Time: 1.87 - Validation Test: 0.16
# 	- [Novato] Individuo 27
# 		- Time: 1.85 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 2.5 - Validation Test: 0.31
# 	- [Novato] Individuo 29
# 		- Time: 2.18 - Validation Test: 0.25
# 	- [Novato] Individuo 30
# 		- Time: 1.97 - Validation Test: 0.36
# 	- [Novato] Individuo 31
# 		- Time: 1.88 - Validation Test: 0.23
# 	- [Novato] Individuo 32
# 		- Time: 2.18 - Validation Test: 0.36
# 	- [Novato] Individuo 33
# 		- Time: 2.17 - Validation Test: 0.27
# 	- [Novato] Individuo 34
# 		- Time: 2.13 - Validation Test: 0.28
# 	- [Novato] Individuo 35
# 		- Time: 1.92 - Validation Test: 0.33
# 	- [Novato] Individuo 36
# 		- Time: 1.94 - Validation Test: 0.33
# 	- [Novato] Individuo 37
# 		- Time: 1.86 - Validation Test: 0.33
# 	- [Novato] Individuo 38
# 		- Time: 2.21 - Validation Test: 0.33
# 	- [Novato] Individuo 39
# 		- Time: 1.92 - Validation Test: 0.0
# 	- [Novato] Individuo 40
# 		- Time: 1.86 - Validation Test: 0.11
# 	- [Novato] Individuo 41
# 		- Time: 2.27 - Validation Test: 0.21
# 	- [Novato] Individuo 42
# 		- Time: 2.14 - Validation Test: 0.37
# 	- [Novato] Individuo 43
# 		- Time: 1.98 - Validation Test: 0.25
# 	- [Novato] Individuo 44
# 		- Time: 2.61 - Validation Test: 0.19
# 	- [Novato] Individuo 45
# 		- Time: 1.88 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 1.89 - Validation Test: 0.23
# 	- [Novato] Individuo 47
# 		- Time: 1.88 - Validation Test: 0.27
# 	- [Novato] Individuo 48
# 		- Time: 3.19 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.27 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.2506560751003544
# 		- esn_params_metrics: 4591672.88
# 		- nn_params_metrics: 206827.58
# - Época 10
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Campeão] Individuo 2
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 3
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 4
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 5
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 6
# 		- Time: 2.17 - Validation Test: 0.43
# 	- [Campeão] Individuo 7
# 		- Time: 1.93 - Validation Test: 0.43
# 	- [Campeão] Individuo 8
# 		- Time: 1.85 - Validation Test: 0.42
# 	- [Campeão] Individuo 9
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Novato] Individuo 10
# 		- Time: 2.16 - Validation Test: 0.25
# 	- [Novato] Individuo 11
# 		- Time: 1.99 - Validation Test: 0.25
# 	- [Novato] Individuo 12
# 		- Time: 2.0 - Validation Test: 0.36
# 	- [Novato] Individuo 13
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Novato] Individuo 14
# 		- Time: 1.96 - Validation Test: 0.32
# 	- [Novato] Individuo 15
# 		- Time: 2.29 - Validation Test: 0.5
# 	- [Novato] Individuo 16
# 		- Time: 1.95 - Validation Test: 0.2
# 	- [Novato] Individuo 17
# 		- Time: 2.02 - Validation Test: 0.35
# 	- [Novato] Individuo 18
# 		- Time: 2.38 - Validation Test: 0.41
# 	- [Novato] Individuo 19
# 		- Time: 2.45 - Validation Test: 0.0
# 	- [Novato] Individuo 20
# 		- Time: 1.89 - Validation Test: 0.3
# 	- [Novato] Individuo 21
# 		- Time: 2.24 - Validation Test: 0.32
# 	- [Novato] Individuo 22
# 		- Time: 2.25 - Validation Test: 0.21
# 	- [Novato] Individuo 23
# 		- Time: 1.98 - Validation Test: 0.29
# 	- [Novato] Individuo 24
# 		- Time: 2.16 - Validation Test: 0.27
# 	- [Novato] Individuo 25
# 		- Time: 2.12 - Validation Test: 0.3
# 	- [Novato] Individuo 26
# 		- Time: 1.92 - Validation Test: 0.42
# 	- [Novato] Individuo 27
# 		- Time: 1.85 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 2.59 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 2.24 - Validation Test: 0.1
# 	- [Novato] Individuo 30
# 		- Time: 1.95 - Validation Test: 0.0
# 	- [Novato] Individuo 31
# 		- Time: 2.13 - Validation Test: 0.36
# 	- [Novato] Individuo 32
# 		- Time: 2.56 - Validation Test: 0.22
# 	- [Novato] Individuo 33
# 		- Time: 1.93 - Validation Test: 0.24
# 	- [Novato] Individuo 34
# 		- Time: 1.98 - Validation Test: 0.27
# 	- [Novato] Individuo 35
# 		- Time: 2.08 - Validation Test: 0.37
# 	- [Novato] Individuo 36
# 		- Time: 2.19 - Validation Test: 0.22
# 	- [Novato] Individuo 37
# 		- Time: 2.37 - Validation Test: 0.17
# 	- [Novato] Individuo 38
# 		- Time: 2.78 - Validation Test: 0.25
# 	- [Novato] Individuo 39
# 		- Time: 1.96 - Validation Test: 0.33
# 	- [Novato] Individuo 40
# 		- Time: 2.36 - Validation Test: 0.37
# 	- [Novato] Individuo 41
# 		- Time: 2.34 - Validation Test: 0.0
# 	- [Novato] Individuo 42
# 		- Time: 2.04 - Validation Test: 0.34
# 	- [Novato] Individuo 43
# 		- Time: 2.36 - Validation Test: 0.39
# 	- [Novato] Individuo 44
# 		- Time: 1.99 - Validation Test: 0.36
# 	- [Novato] Individuo 45
# 		- Time: 2.03 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 1.86 - Validation Test: 0.0
# 	- [Novato] Individuo 47
# 		- Time: 2.05 - Validation Test: 0.0
# 	- [Novato] Individuo 48
# 		- Time: 3.12 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.33 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.2789767780475939
# 		- esn_params_metrics: 4998277.34
# 		- nn_params_metrics: 188539.42
# - Época 11
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.29 - Validation Test: 0.5
# 	- [Campeão] Individuo 2
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Campeão] Individuo 3
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 4
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 5
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 6
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 7
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 8
# 		- Time: 2.38 - Validation Test: 0.49
# 	- [Campeão] Individuo 9
# 		- Time: 2.17 - Validation Test: 0.43
# 	- [Novato] Individuo 10
# 		- Time: 2.36 - Validation Test: 0.0
# 	- [Novato] Individuo 11
# 		- Time: 1.94 - Validation Test: 0.21
# 	- [Novato] Individuo 12
# 		- Time: 2.0 - Validation Test: 0.42
# 	- [Novato] Individuo 13
# 		- Time: 2.3 - Validation Test: 0.27
# 	- [Novato] Individuo 14
# 		- Time: 2.19 - Validation Test: 0.19
# 	- [Novato] Individuo 15
# 		- Time: 2.36 - Validation Test: 0.06
# 	- [Novato] Individuo 16
# 		- Time: 2.01 - Validation Test: 0.46
# 	- [Novato] Individuo 17
# 		- Time: 2.79 - Validation Test: 0.12
# 	- [Novato] Individuo 18
# 		- Time: 2.35 - Validation Test: 0.39
# 	- [Novato] Individuo 19
# 		- Time: 2.41 - Validation Test: 0.31
# 	- [Novato] Individuo 20
# 		- Time: 2.43 - Validation Test: 0.26
# 	- [Novato] Individuo 21
# 		- Time: 2.02 - Validation Test: 0.42
# 	- [Novato] Individuo 22
# 		- Time: 1.9 - Validation Test: 0.22
# 	- [Novato] Individuo 23
# 		- Time: 1.96 - Validation Test: 0.21
# 	- [Novato] Individuo 24
# 		- Time: 2.34 - Validation Test: 0.36
# 	- [Novato] Individuo 25
# 		- Time: 2.47 - Validation Test: 0.1
# 	- [Novato] Individuo 26
# 		- Time: 2.41 - Validation Test: 0.3
# 	- [Novato] Individuo 27
# 		- Time: 1.93 - Validation Test: 0.24
# 	- [Novato] Individuo 28
# 		- Time: 2.77 - Validation Test: 0.29
# 	- [Novato] Individuo 29
# 		- Time: 2.31 - Validation Test: 0.38
# 	- [Novato] Individuo 30
# 		- Time: 2.35 - Validation Test: 0.28
# 	- [Novato] Individuo 31
# 		- Time: 2.21 - Validation Test: 0.31
# 	- [Novato] Individuo 32
# 		- Time: 2.34 - Validation Test: 0.25
# 	- [Novato] Individuo 33
# 		- Time: 1.96 - Validation Test: 0.06
# 	- [Novato] Individuo 34
# 		- Time: 1.91 - Validation Test: 0.0
# 	- [Novato] Individuo 35
# 		- Time: 2.38 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 2.05 - Validation Test: 0.0
# 	- [Novato] Individuo 37
# 		- Time: 2.28 - Validation Test: 0.16
# 	- [Novato] Individuo 38
# 		- Time: 2.23 - Validation Test: 0.21
# 	- [Novato] Individuo 39
# 		- Time: 1.93 - Validation Test: 0.27
# 	- [Novato] Individuo 40
# 		- Time: 2.26 - Validation Test: 0.29
# 	- [Novato] Individuo 41
# 		- Time: 2.33 - Validation Test: 0.2
# 	- [Novato] Individuo 42
# 		- Time: 2.38 - Validation Test: 0.12
# 	- [Novato] Individuo 43
# 		- Time: 2.34 - Validation Test: 0.2
# 	- [Novato] Individuo 44
# 		- Time: 2.4 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 1.89 - Validation Test: 0.23
# 	- [Novato] Individuo 46
# 		- Time: 1.97 - Validation Test: 0.17
# 	- [Novato] Individuo 47
# 		- Time: 2.2 - Validation Test: 0.33
# 	- [Novato] Individuo 48
# 		- Time: 2.67 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.5 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.2621666563679337
# 		- esn_params_metrics: 5561728.64
# 		- nn_params_metrics: 153768.66
# - Época 12
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.29 - Validation Test: 0.5
# 	- [Campeão] Individuo 2
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Campeão] Individuo 3
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 4
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 5
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 6
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 7
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 8
# 		- Time: 2.01 - Validation Test: 0.46
# 	- [Campeão] Individuo 9
# 		- Time: 2.17 - Validation Test: 0.43
# 	- [Novato] Individuo 10
# 		- Time: 2.04 - Validation Test: 0.06
# 	- [Novato] Individuo 11
# 		- Time: 2.12 - Validation Test: 0.1
# 	- [Novato] Individuo 12
# 		- Time: 2.3 - Validation Test: 0.06
# 	- [Novato] Individuo 13
# 		- Time: 2.23 - Validation Test: 0.28
# 	- [Novato] Individuo 14
# 		- Time: 1.91 - Validation Test: 0.18
# 	- [Novato] Individuo 15
# 		- Time: 2.25 - Validation Test: 0.4
# 	- [Novato] Individuo 16
# 		- Time: 2.02 - Validation Test: 0.11
# 	- [Novato] Individuo 17
# 		- Time: 1.93 - Validation Test: 0.2
# 	- [Novato] Individuo 18
# 		- Time: 1.95 - Validation Test: 0.21
# 	- [Novato] Individuo 19
# 		- Time: 2.36 - Validation Test: 0.26
# 	- [Novato] Individuo 20
# 		- Time: 2.06 - Validation Test: 0.46
# 	- [Novato] Individuo 21
# 		- Time: 2.38 - Validation Test: 0.22
# 	- [Novato] Individuo 22
# 		- Time: 2.1 - Validation Test: 0.24
# 	- [Novato] Individuo 23
# 		- Time: 2.47 - Validation Test: 0.21
# 	- [Novato] Individuo 24
# 		- Time: 2.09 - Validation Test: 0.26
# 	- [Novato] Individuo 25
# 		- Time: 1.91 - Validation Test: 0.31
# 	- [Novato] Individuo 26
# 		- Time: 2.11 - Validation Test: 0.29
# 	- [Novato] Individuo 27
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Novato] Individuo 28
# 		- Time: 2.36 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 1.91 - Validation Test: 0.3
# 	- [Novato] Individuo 30
# 		- Time: 2.03 - Validation Test: 0.29
# 	- [Novato] Individuo 31
# 		- Time: 2.01 - Validation Test: 0.38
# 	- [Novato] Individuo 32
# 		- Time: 2.12 - Validation Test: 0.21
# 	- [Novato] Individuo 33
# 		- Time: 2.01 - Validation Test: 0.26
# 	- [Novato] Individuo 34
# 		- Time: 1.9 - Validation Test: 0.33
# 	- [Novato] Individuo 35
# 		- Time: 1.91 - Validation Test: 0.35
# 	- [Novato] Individuo 36
# 		- Time: 2.1 - Validation Test: 0.11
# 	- [Novato] Individuo 37
# 		- Time: 2.21 - Validation Test: 0.33
# 	- [Novato] Individuo 38
# 		- Time: 2.45 - Validation Test: 0.0
# 	- [Novato] Individuo 39
# 		- Time: 2.62 - Validation Test: 0.23
# 	- [Novato] Individuo 40
# 		- Time: 2.4 - Validation Test: 0.0
# 	- [Novato] Individuo 41
# 		- Time: 1.92 - Validation Test: 0.19
# 	- [Novato] Individuo 42
# 		- Time: 2.33 - Validation Test: 0.29
# 	- [Novato] Individuo 43
# 		- Time: 1.88 - Validation Test: 0.4
# 	- [Novato] Individuo 44
# 		- Time: 2.08 - Validation Test: 0.39
# 	- [Novato] Individuo 45
# 		- Time: 2.11 - Validation Test: 0.34
# 	- [Novato] Individuo 46
# 		- Time: 1.85 - Validation Test: 0.11
# 	- [Novato] Individuo 47
# 		- Time: 1.89 - Validation Test: 0.0
# 	- [Novato] Individuo 48
# 		- Time: 2.94 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 2.19 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.27201191409766623
# 		- esn_params_metrics: 4838666.44
# 		- nn_params_metrics: 191529.42
# - Época 13
# 	- [Campeão] Individuo 0
# 		- Time: 2.21 - Validation Test: 0.56
# 	- [Campeão] Individuo 1
# 		- Time: 2.29 - Validation Test: 0.5
# 	- [Campeão] Individuo 2
# 		- Time: 2.37 - Validation Test: 0.51
# 	- [Campeão] Individuo 3
# 		- Time: 2.54 - Validation Test: 0.5
# 	- [Campeão] Individuo 4
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 5
# 		- Time: 1.89 - Validation Test: 0.47
# 	- [Campeão] Individuo 6
# 		- Time: 2.14 - Validation Test: 0.49
# 	- [Campeão] Individuo 7
# 		- Time: 2.06 - Validation Test: 0.46
# 	- [Campeão] Individuo 8
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Campeão] Individuo 9
# 		- Time: 1.88 - Validation Test: 0.44
# 	- [Novato] Individuo 10
# 		- Time: 2.15 - Validation Test: 0.29
# 	- [Novato] Individuo 11
# 		- Time: 2.04 - Validation Test: 0.0
# 	- [Novato] Individuo 12
# 		- Time: 2.31 - Validation Test: 0.06
# 	- [Novato] Individuo 13
# 		- Time: 1.97 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 1.9 - Validation Test: 0.26
# 	- [Novato] Individuo 15
# 		- Time: 2.24 - Validation Test: 0.12
# 	- [Novato] Individuo 16
# 		- Time: 2.3 - Validation Test: 0.0
# 	- [Novato] Individuo 17
# 		- Time: 2.01 - Validation Test: 0.41
# 	- [Novato] Individuo 18
# 		- Time: 1.99 - Validation Test: 0.0
# 	- [Novato] Individuo 19
# 		- Time: 2.1 - Validation Test: 0.24
# 	- [Novato] Individuo 20
# 		- Time: 2.42 - Validation Test: 0.21
# 	- [Novato] Individuo 21
# ...
# 	- [Novato] Individuo 31
# 		- Time: 4.29 - Validation Test: 0.17
# 	- [Novato] Individuo 32
# 		- Time: 5.44 - Validation Test: 0.41
# 	- [Novato] Individuo 33
# 		- Time: 3.82 - Validation Test: 0.06
# 	- [Novato] Individuo 34
# 		- Time: 7.55 - Validation Test: 0.2
# 	- [Novato] Individuo 35
# 		- Time: 9.67 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 6.36 - Validation Test: 0.31
# 	- [Novato] Individuo 37
# 		- Time: 7.32 - Validation Test: 0.24
# 	- [Novato] Individuo 38
# 		- Time: 5.79 - Validation Test: 0.06
# 	- [Novato] Individuo 39
# 		- Time: 6.98 - Validation Test: 0.28
# 	- [Novato] Individuo 40
# 		- Time: 6.61 - Validation Test: 0.2
# 	- [Novato] Individuo 41
# 		- Time: 6.28 - Validation Test: 0.38
# 	- [Novato] Individuo 42
# 		- Time: 5.3 - Validation Test: 0.29
# 	- [Novato] Individuo 43
# 		- Time: 6.07 - Validation Test: 0.43
# 	- [Novato] Individuo 44
# 		- Time: 6.74 - Validation Test: 0.22
# 	- [Novato] Individuo 45
# 		- Time: 5.12 - Validation Test: 0.21
# 	- [Novato] Individuo 46
# 		- Time: 7.0 - Validation Test: 0.26
# 	- [Novato] Individuo 47
# 		- Time: 5.33 - Validation Test: 0.38
# 	- [Novato] Individuo 48
# 		- Time: 5.43 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 4.16 - Validation Test: 0.35
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.30607302658544727
# 		- esn_params_metrics: 5204308.16
# 		- nn_params_metrics: 171657.52
# - Época 196
# 	- [Campeão] Individuo 0
# 		- Time: 5.26 - Validation Test: 0.7
# 	- [Campeão] Individuo 1
# 		- Time: 3.9 - Validation Test: 0.67
# 	- [Campeão] Individuo 2
# 		- Time: 4.17 - Validation Test: 0.67
# 	- [Campeão] Individuo 3
# 		- Time: 5.03 - Validation Test: 0.65
# 	- [Campeão] Individuo 4
# 		- Time: 3.71 - Validation Test: 0.65
# 	- [Campeão] Individuo 5
# 		- Time: 5.27 - Validation Test: 0.65
# 	- [Campeão] Individuo 6
# 		- Time: 4.75 - Validation Test: 0.65
# 	- [Campeão] Individuo 7
# 		- Time: 3.98 - Validation Test: 0.64
# 	- [Campeão] Individuo 8
# 		- Time: 3.51 - Validation Test: 0.63
# 	- [Campeão] Individuo 9
# 		- Time: 3.37 - Validation Test: 0.61
# 	- [Novato] Individuo 10
# 		- Time: 5.38 - Validation Test: 0.64
# 	- [Novato] Individuo 11
# 		- Time: 5.46 - Validation Test: 0.0
# 	- [Novato] Individuo 12
# 		- Time: 6.23 - Validation Test: 0.0
# 	- [Novato] Individuo 13
# 		- Time: 5.37 - Validation Test: 0.34
# 	- [Novato] Individuo 14
# 		- Time: 5.9 - Validation Test: 0.35
# 	- [Novato] Individuo 15
# 		- Time: 5.25 - Validation Test: 0.36
# 	- [Novato] Individuo 16
# 		- Time: 5.36 - Validation Test: 0.52
# 	- [Novato] Individuo 17
# 		- Time: 4.71 - Validation Test: 0.05
# 	- [Novato] Individuo 18
# 		- Time: 4.43 - Validation Test: 0.26
# 	- [Novato] Individuo 19
# 		- Time: 4.78 - Validation Test: 0.0
# 	- [Novato] Individuo 20
# 		- Time: 5.6 - Validation Test: 0.18
# 	- [Novato] Individuo 21
# 		- Time: 4.03 - Validation Test: 0.0
# 	- [Novato] Individuo 22
# 		- Time: 5.6 - Validation Test: 0.0
# 	- [Novato] Individuo 23
# 		- Time: 5.56 - Validation Test: 0.48
# 	- [Novato] Individuo 24
# 		- Time: 6.74 - Validation Test: 0.52
# 	- [Novato] Individuo 25
# 		- Time: 4.24 - Validation Test: 0.35
# 	- [Novato] Individuo 26
# 		- Time: 6.71 - Validation Test: 0.0
# 	- [Novato] Individuo 27
# 		- Time: 5.12 - Validation Test: 0.12
# 	- [Novato] Individuo 28
# 		- Time: 5.18 - Validation Test: 0.32
# 	- [Novato] Individuo 29
# 		- Time: 5.58 - Validation Test: 0.42
# 	- [Novato] Individuo 30
# 		- Time: 5.84 - Validation Test: 0.34
# 	- [Novato] Individuo 31
# 		- Time: 6.2 - Validation Test: 0.51
# 	- [Novato] Individuo 32
# 		- Time: 6.67 - Validation Test: 0.53
# 	- [Novato] Individuo 33
# 		- Time: 5.14 - Validation Test: 0.32
# 	- [Novato] Individuo 34
# 		- Time: 6.37 - Validation Test: 0.06
# 	- [Novato] Individuo 35
# 		- Time: 5.18 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 5.54 - Validation Test: 0.32
# 	- [Novato] Individuo 37
# 		- Time: 4.04 - Validation Test: 0.0
# 	- [Novato] Individuo 38
# 		- Time: 4.4 - Validation Test: 0.35
# 	- [Novato] Individuo 39
# 		- Time: 4.75 - Validation Test: 0.32
# 	- [Novato] Individuo 40
# 		- Time: 4.15 - Validation Test: 0.0
# 	- [Novato] Individuo 41
# 		- Time: 5.96 - Validation Test: 0.37
# 	- [Novato] Individuo 42
# 		- Time: 5.61 - Validation Test: 0.36
# 	- [Novato] Individuo 43
# 		- Time: 4.17 - Validation Test: 0.0
# 	- [Novato] Individuo 44
# 		- Time: 6.29 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 4.56 - Validation Test: 0.0
# 	- [Novato] Individuo 46
# 		- Time: 4.66 - Validation Test: 0.48
# 	- [Novato] Individuo 47
# 		- Time: 4.93 - Validation Test: 0.12
# 	- [Novato] Individuo 48
# 		- Time: 5.41 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 4.86 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.3102739667484479
# 		- esn_params_metrics: 4885297.54
# 		- nn_params_metrics: 111445.16
# - Época 197
# 	- [Campeão] Individuo 0
# 		- Time: 5.26 - Validation Test: 0.7
# 	- [Campeão] Individuo 1
# 		- Time: 3.9 - Validation Test: 0.67
# 	- [Campeão] Individuo 2
# 		- Time: 4.17 - Validation Test: 0.67
# 	- [Campeão] Individuo 3
# 		- Time: 5.03 - Validation Test: 0.65
# 	- [Campeão] Individuo 4
# 		- Time: 5.38 - Validation Test: 0.64
# 	- [Campeão] Individuo 5
# 		- Time: 3.71 - Validation Test: 0.65
# 	- [Campeão] Individuo 6
# 		- Time: 5.27 - Validation Test: 0.65
# 	- [Campeão] Individuo 7
# 		- Time: 4.75 - Validation Test: 0.65
# 	- [Campeão] Individuo 8
# 		- Time: 3.51 - Validation Test: 0.63
# 	- [Campeão] Individuo 9
# 		- Time: 3.98 - Validation Test: 0.64
# 	- [Novato] Individuo 10
# 		- Time: 5.37 - Validation Test: 0.33
# 	- [Novato] Individuo 11
# 		- Time: 5.7 - Validation Test: 0.47
# 	- [Novato] Individuo 12
# 		- Time: 5.05 - Validation Test: 0.3
# 	- [Novato] Individuo 13
# 		- Time: 7.03 - Validation Test: 0.12
# 	- [Novato] Individuo 14
# 		- Time: 5.49 - Validation Test: 0.33
# 	- [Novato] Individuo 15
# 		- Time: 4.69 - Validation Test: 0.16
# 	- [Novato] Individuo 16
# 		- Time: 5.16 - Validation Test: 0.34
# 	- [Novato] Individuo 17
# 		- Time: 5.35 - Validation Test: 0.12
# 	- [Novato] Individuo 18
# 		- Time: 5.83 - Validation Test: 0.21
# 	- [Novato] Individuo 19
# 		- Time: 5.54 - Validation Test: 0.32
# 	- [Novato] Individuo 20
# 		- Time: 6.76 - Validation Test: 0.12
# 	- [Novato] Individuo 21
# 		- Time: 6.89 - Validation Test: 0.44
# 	- [Novato] Individuo 22
# 		- Time: 5.55 - Validation Test: 0.31
# 	- [Novato] Individuo 23
# 		- Time: 6.83 - Validation Test: 0.0
# 	- [Novato] Individuo 24
# 		- Time: 4.6 - Validation Test: 0.0
# 	- [Novato] Individuo 25
# 		- Time: 6.31 - Validation Test: 0.45
# 	- [Novato] Individuo 26
# 		- Time: 6.8 - Validation Test: 0.45
# 	- [Novato] Individuo 27
# 		- Time: 5.0 - Validation Test: 0.37
# 	- [Novato] Individuo 28
# 		- Time: 3.98 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 5.06 - Validation Test: 0.0
# 	- [Novato] Individuo 30
# 		- Time: 4.89 - Validation Test: 0.43
# 	- [Novato] Individuo 31
# 		- Time: 5.17 - Validation Test: 0.0
# 	- [Novato] Individuo 32
# 		- Time: 6.15 - Validation Test: 0.17
# 	- [Novato] Individuo 33
# 		- Time: 6.04 - Validation Test: 0.0
# 	- [Novato] Individuo 34
# 		- Time: 6.06 - Validation Test: 0.43
# 	- [Novato] Individuo 35
# 		- Time: 5.66 - Validation Test: 0.45
# 	- [Novato] Individuo 36
# 		- Time: 4.42 - Validation Test: 0.3
# 	- [Novato] Individuo 37
# 		- Time: 4.47 - Validation Test: 0.32
# 	- [Novato] Individuo 38
# 		- Time: 5.65 - Validation Test: 0.22
# 	- [Novato] Individuo 39
# 		- Time: 5.61 - Validation Test: 0.35
# 	- [Novato] Individuo 40
# 		- Time: 5.06 - Validation Test: 0.48
# 	- [Novato] Individuo 41
# 		- Time: 5.01 - Validation Test: 0.38
# 	- [Novato] Individuo 42
# 		- Time: 4.09 - Validation Test: 0.38
# 	- [Novato] Individuo 43
# 		- Time: 6.8 - Validation Test: 0.0
# 	- [Novato] Individuo 44
# 		- Time: 5.88 - Validation Test: 0.3
# 	- [Novato] Individuo 45
# 		- Time: 5.25 - Validation Test: 0.33
# 	- [Novato] Individuo 46
# 		- Time: 6.0 - Validation Test: 0.32
# 	- [Novato] Individuo 47
# 		- Time: 5.16 - Validation Test: 0.0
# 	- [Novato] Individuo 48
# 		- Time: 5.84 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 6.53 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.325499974899482
# 		- esn_params_metrics: 4613838.38
# 		- nn_params_metrics: 127876.32
# - Época 198
# 	- [Campeão] Individuo 0
# 		- Time: 5.26 - Validation Test: 0.7
# 	- [Campeão] Individuo 1
# 		- Time: 3.9 - Validation Test: 0.67
# 	- [Campeão] Individuo 2
# 		- Time: 4.17 - Validation Test: 0.67
# 	- [Campeão] Individuo 3
# 		- Time: 5.03 - Validation Test: 0.65
# 	- [Campeão] Individuo 4
# 		- Time: 5.38 - Validation Test: 0.64
# 	- [Campeão] Individuo 5
# 		- Time: 5.27 - Validation Test: 0.65
# 	- [Campeão] Individuo 6
# 		- Time: 4.75 - Validation Test: 0.65
# 	- [Campeão] Individuo 7
# 		- Time: 3.71 - Validation Test: 0.65
# 	- [Campeão] Individuo 8
# 		- Time: 3.98 - Validation Test: 0.64
# 	- [Campeão] Individuo 9
# 		- Time: 3.51 - Validation Test: 0.63
# 	- [Novato] Individuo 10
# 		- Time: 5.47 - Validation Test: 0.42
# 	- [Novato] Individuo 11
# 		- Time: 5.01 - Validation Test: 0.23
# 	- [Novato] Individuo 12
# 		- Time: 4.52 - Validation Test: 0.31
# 	- [Novato] Individuo 13
# 		- Time: 4.38 - Validation Test: 0.0
# 	- [Novato] Individuo 14
# 		- Time: 5.99 - Validation Test: 0.39
# 	- [Novato] Individuo 15
# 		- Time: 4.53 - Validation Test: 0.38
# 	- [Novato] Individuo 16
# 		- Time: 3.94 - Validation Test: 0.37
# 	- [Novato] Individuo 17
# 		- Time: 5.31 - Validation Test: 0.32
# 	- [Novato] Individuo 18
# 		- Time: 4.51 - Validation Test: 0.11
# 	- [Novato] Individuo 19
# 		- Time: 5.42 - Validation Test: 0.26
# 	- [Novato] Individuo 20
# 		- Time: 5.06 - Validation Test: 0.48
# 	- [Novato] Individuo 21
# 		- Time: 5.93 - Validation Test: 0.42
# 	- [Novato] Individuo 22
# 		- Time: 4.63 - Validation Test: 0.41
# 	- [Novato] Individuo 23
# 		- Time: 4.18 - Validation Test: 0.3
# 	- [Novato] Individuo 24
# 		- Time: 4.51 - Validation Test: 0.42
# 	- [Novato] Individuo 25
# 		- Time: 5.15 - Validation Test: 0.06
# 	- [Novato] Individuo 26
# 		- Time: 4.52 - Validation Test: 0.33
# 	- [Novato] Individuo 27
# 		- Time: 4.52 - Validation Test: 0.43
# 	- [Novato] Individuo 28
# 		- Time: 4.27 - Validation Test: 0.22
# 	- [Novato] Individuo 29
# 		- Time: 5.04 - Validation Test: 0.24
# 	- [Novato] Individuo 30
# 		- Time: 5.58 - Validation Test: 0.49
# 	- [Novato] Individuo 31
# 		- Time: 5.19 - Validation Test: 0.22
# 	- [Novato] Individuo 32
# 		- Time: 7.48 - Validation Test: 0.24
# 	- [Novato] Individuo 33
# 		- Time: 5.4 - Validation Test: 0.26
# 	- [Novato] Individuo 34
# 		- Time: 5.31 - Validation Test: 0.28
# 	- [Novato] Individuo 35
# 		- Time: 5.72 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 6.83 - Validation Test: 0.24
# 	- [Novato] Individuo 37
# 		- Time: 5.91 - Validation Test: 0.17
# 	- [Novato] Individuo 38
# 		- Time: 4.71 - Validation Test: 0.39
# 	- [Novato] Individuo 39
# 		- Time: 5.79 - Validation Test: 0.39
# 	- [Novato] Individuo 40
# 		- Time: 4.89 - Validation Test: 0.25
# 	- [Novato] Individuo 41
# 		- Time: 4.82 - Validation Test: 0.28
# 	- [Novato] Individuo 42
# 		- Time: 5.08 - Validation Test: 0.29
# 	- [Novato] Individuo 43
# 		- Time: 4.94 - Validation Test: 0.0
# 	- [Novato] Individuo 44
# 		- Time: 4.65 - Validation Test: 0.25
# 	- [Novato] Individuo 45
# 		- Time: 4.92 - Validation Test: 0.27
# 	- [Novato] Individuo 46
# 		- Time: 5.9 - Validation Test: 0.46
# 	- [Novato] Individuo 47
# 		- Time: 4.3 - Validation Test: 0.22
# 	- [Novato] Individuo 48
# 		- Time: 6.27 - Validation Test: 0.0
# 	- [Novato] Individuo 49
# 		- Time: 4.05 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.34724852308346543
# 		- esn_params_metrics: 4475131.68
# 		- nn_params_metrics: 115879.0
# - Época 199
# 	- [Campeão] Individuo 0
# 		- Time: 5.26 - Validation Test: 0.7
# 	- [Campeão] Individuo 1
# 		- Time: 3.9 - Validation Test: 0.67
# 	- [Campeão] Individuo 2
# 		- Time: 4.17 - Validation Test: 0.67
# 	- [Campeão] Individuo 3
# 		- Time: 5.03 - Validation Test: 0.65
# 	- [Campeão] Individuo 4
# 		- Time: 5.38 - Validation Test: 0.64
# 	- [Campeão] Individuo 5
# 		- Time: 3.71 - Validation Test: 0.65
# 	- [Campeão] Individuo 6
# 		- Time: 5.27 - Validation Test: 0.65
# 	- [Campeão] Individuo 7
# 		- Time: 4.75 - Validation Test: 0.65
# 	- [Campeão] Individuo 8
# 		- Time: 3.51 - Validation Test: 0.63
# 	- [Campeão] Individuo 9
# 		- Time: 3.98 - Validation Test: 0.64
# 	- [Novato] Individuo 10
# 		- Time: 7.27 - Validation Test: 0.15
# 	- [Novato] Individuo 11
# 		- Time: 5.0 - Validation Test: 0.21
# 	- [Novato] Individuo 12
# 		- Time: 4.97 - Validation Test: 0.21
# 	- [Novato] Individuo 13
# 		- Time: 5.62 - Validation Test: 0.26
# 	- [Novato] Individuo 14
# 		- Time: 4.54 - Validation Test: 0.23
# 	- [Novato] Individuo 15
# 		- Time: 5.95 - Validation Test: 0.38
# 	- [Novato] Individuo 16
# 		- Time: 5.26 - Validation Test: 0.41
# 	- [Novato] Individuo 17
# 		- Time: 3.97 - Validation Test: 0.23
# 	- [Novato] Individuo 18
# 		- Time: 4.55 - Validation Test: 0.12
# 	- [Novato] Individuo 19
# 		- Time: 3.73 - Validation Test: 0.0
# 	- [Novato] Individuo 20
# 		- Time: 5.03 - Validation Test: 0.31
# 	- [Novato] Individuo 21
# 		- Time: 4.16 - Validation Test: 0.3
# 	- [Novato] Individuo 22
# 		- Time: 6.15 - Validation Test: 0.28
# 	- [Novato] Individuo 23
# 		- Time: 7.13 - Validation Test: 0.39
# 	- [Novato] Individuo 24
# 		- Time: 4.86 - Validation Test: 0.35
# 	- [Novato] Individuo 25
# 		- Time: 5.73 - Validation Test: 0.38
# 	- [Novato] Individuo 26
# 		- Time: 5.75 - Validation Test: 0.33
# 	- [Novato] Individuo 27
# 		- Time: 4.76 - Validation Test: 0.0
# 	- [Novato] Individuo 28
# 		- Time: 3.92 - Validation Test: 0.0
# 	- [Novato] Individuo 29
# 		- Time: 5.03 - Validation Test: 0.0
# 	- [Novato] Individuo 30
# 		- Time: 3.72 - Validation Test: 0.0
# 	- [Novato] Individuo 31
# 		- Time: 5.5 - Validation Test: 0.42
# 	- [Novato] Individuo 32
# 		- Time: 4.67 - Validation Test: 0.52
# 	- [Novato] Individuo 33
# 		- Time: 4.73 - Validation Test: 0.33
# 	- [Novato] Individuo 34
# 		- Time: 5.79 - Validation Test: 0.26
# 	- [Novato] Individuo 35
# 		- Time: 4.55 - Validation Test: 0.0
# 	- [Novato] Individuo 36
# 		- Time: 5.52 - Validation Test: 0.22
# 	- [Novato] Individuo 37
# 		- Time: 3.82 - Validation Test: 0.06
# 	- [Novato] Individuo 38
# 		- Time: 4.37 - Validation Test: 0.0
# 	- [Novato] Individuo 39
# 		- Time: 5.52 - Validation Test: 0.0
# 	- [Novato] Individuo 40
# 		- Time: 4.39 - Validation Test: 0.0
# 	- [Novato] Individuo 41
# 		- Time: 4.68 - Validation Test: 0.3
# 	- [Novato] Individuo 42
# 		- Time: 5.56 - Validation Test: 0.34
# 	- [Novato] Individuo 43
# 		- Time: 3.77 - Validation Test: 0.17
# 	- [Novato] Individuo 44
# 		- Time: 5.61 - Validation Test: 0.0
# 	- [Novato] Individuo 45
# 		- Time: 5.83 - Validation Test: 0.26
# 	- [Novato] Individuo 46
# 		- Time: 5.69 - Validation Test: 0.42
# 	- [Novato] Individuo 47
# 		- Time: 3.71 - Validation Test: 0.0
# 	- [Novato] Individuo 48
# 		- Time: 4.2 - Validation Test: 0.15
# 	- [Novato] Individuo 49
# 		- Time: 5.16 - Validation Test: 0.0
# 	 - Executa fitness_function
# save_score_array
# (50, 21)
# 50
# 	 - Executa tournament
# 	 - random_crossover
# 	A nova geração terá:
# 		- 38 população cruzada
# 		- 2 população aleatória
# 	 - childrens: (40, 45)
# 	 - mutation - childrens: (40, 45)
# 	 - reinsertion - childrens: (50, 45)
# 	 - Métricas:
# 		- validation_metrics: 0.2909339882855082
# 		- esn_params_metrics: 4709810.88
# 		- nn_params_metrics: 115128.84
